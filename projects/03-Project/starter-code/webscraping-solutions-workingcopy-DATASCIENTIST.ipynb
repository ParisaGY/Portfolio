# %% [markdown]
# # Webscraping 2.0
#
# Joseph Nelson, DC
#
# In today's codealong, I'll walkthrough how to build a scraper using urllib and BeautifulSoup. We'll discover the problems we discussed in the lesson readme associated with doing so, and we'll remedy this problem using a headless browser called Selenium.

# %%
# import
from selenium import webdriver
from time import sleep
from bs4 import BeautifulSoup
import urllib

# %% [markdown]
# ## Data_scientist_DC_75_entry

# %%
driver = webdriver.Chrome()
url = "https://www.indeed.com/jobs?q=%22Data+Scientist%22+$75,000&l=%22Washington,+DC%22&radius=100&explvl=entry_level&limit=100"
driver.get(url)
# wait one second
sleep(1)
#grab the page source
html = driver.page_source
# BeautifulSoup it!
html = BeautifulSoup(html)
driver.close()

# I'm going to create my empty df first
import pandas as pd
dcarea_job1 = pd.DataFrame(columns=["Company_name"])
dcarea_job2 = pd.DataFrame(columns=["Location","Salary", "Title","Experience"])
# loop through each entry
for company in html.find_all('span', {'class':'company'}):
    name_comp = company.text
    dcarea_job1.loc[len(dcarea_job1)]=[name_comp]
    
for location in html.find_all('span', {'class':'location'}):
    loc_comp = location.text
    salary = 75000
    experience = "Entry_level"
    # try to find the number of bookings
    title = "Data_Scientist"
    dcarea_job2.loc[len(dcarea_job2)]=[loc_comp,salary,title,experience]

dcarea_job1['Company_name'] = dcarea_job1['Company_name'].str.replace('\n', '')
dcarea_job2['Location'] = dcarea_job2['Location'].str.replace('\n', '')

result_DC_75_entry = pd.concat([dcarea_job1, dcarea_job2], axis=1)

result_DC_75_entry
# Out:
#                                          Company_name  \
# 0                                  Predictive Science
# 1                                Engility Corporation
# 2           Massachusetts Institute of Technology ...
# 3                                 Booz Allen Hamilton
# 4                                 Booz Allen Hamilton
# 5                                 Booz Allen Hamilton
# 6                              University of Virginia
# 7                                           Vox Media
# 8                                            Deloitte
# 9                                 Booz Allen Hamilton
# 10                                     Grant Thornton
# 11                                Booz Allen Hamilton
# 12                                Booz Allen Hamilton
# 13                                 Gryphon Scientific
# 14                                         IBM Kenexa
# 15                                 Jobspring Partners
# 16                                               SAIC
# 17                                               CACI
# 18                                    Lockheed Martin
# 19                                  Cubic Corporation
# 20                                                IBM
# 21                                PKW Associates, Inc
# 22                          Trinity Global Consulting
# 23                               Engility Corporation
# 24                                  Next Step Systems
# 25                                Booz Allen Hamilton
# 26                                               CCRi
# 27                                          Accenture
# 28                     Synchronoss Technologies, Inc.
# 29                                        Synchronoss
# 30           Veteran Staffing Network of Easter Seals
# 31                    Whiteboard Federal Technologies
# 32                                SRL TotalSource LLC
# 33                             Encore Search Partners
# 34                                  Mitre Corporation
# 35                      Systems & Technology Research
# 36                                       AboutWeb LLC
# 37                                     WhiteHawk Inc.
# 38                     Logistics Management Institute
# 39                                            Bechtel
# 40                                        ROI Checker
# 41                                 Jobspring Partners
# 42               Commonwealth Computer Research, Inc.
# 43                                Berico Technologies
# 44                             Intelligent Automation
# 45                                        Capital One
# 46                     Synchronoss Technologies, Inc.
# 47                                Booz Allen Hamilton
# 48                                Sphere of Influence
# 49                                   All-In Analytics
# 50                                                PAE
# 51                    Whiteboard Federal Technologies
# 52                                Sphere of Influence
# 53                                     Selby Jennings
# 54                                      BridgeView IT
# 55                                                PAE
# 56                                   The Select Group
# 57                                           Zoomdata
#
#                                              Location   Salary  \
# 0                                       United States  75000.0
# 1                                  Bethesda, MD 20892  75000.0
# 2                                         Provost, VA  75000.0
# 3                                      Washington, DC  75000.0
# 4                                      Washington, DC  75000.0
# 5                                      Alexandria, VA  75000.0
# 6                                 Charlottesville, VA  75000.0
# 7                                      Washington, DC  75000.0
# 8   Arlington, VA 22209 (Radnor-Ft Myer Heights area)  75000.0
# 9                                      Alexandria, VA  75000.0
# 10     Alexandria, VA 22314 (Southwest Quadrant area)  75000.0
# 11                                Chantilly, VA 20151  75000.0
# 12                                         McLean, VA  75000.0
# 13                                    Takoma Park, MD  75000.0
# 14                                     Washington, DC  75000.0
# 15           Washington, DC 20005 (Logan Circle area)  75000.0
# 16                                         McLean, VA  75000.0
# 17                   Washington, DC 20001 (Shaw area)  75000.0
# 18                                      Rockville, MD  75000.0
# 19                                      Tidewater, VA  75000.0
# 20           Washington, DC 20005 (Logan Circle area)  75000.0
# 21                                         Reston, VA  75000.0
# 22                                    Springfield, VA  75000.0
# 23                                 Bethesda, MD 20892  75000.0
# 24                                     Washington, DC  75000.0
# 25                                         McLean, VA  75000.0
# 26                                Charlottesville, VA  75000.0
# 27                                        Rosslyn, VA  75000.0
# 28                                         Reston, VA  75000.0
# 29                                         Reston, VA  75000.0
# 30                                         McLean, VA  75000.0
# 31                                        Herndon, VA  75000.0
# 32                                     Washington, DC  75000.0
# 33                                         Reston, VA  75000.0
# 34                                         McLean, VA  75000.0
# 35                Arlington, VA 22203 (Bluemont area)  75000.0
# 36                                   Vienna, VA 22182  75000.0
# 37                                      Baltimore, MD  75000.0
# 38                                         McLean, VA  75000.0
# 39                                         Reston, VA  75000.0
# 40                                   Vienna, VA 22180  75000.0
# 41                                         McLean, VA  75000.0
# 42          Charlottesville, VA 22901 (29 North area)  75000.0
# 43                                   Gaithersburg, MD  75000.0
# 44                                Rockville, MD 20855  75000.0
# 45                                         McLean, VA  75000.0
# 46                                         Reston, VA  75000.0
# 47                                     Alexandria, VA  75000.0
# 48                                         McLean, VA  75000.0
# 49                                     Washington, DC  75000.0
# 50                             Falls Church, VA 22043  75000.0
# 51                                      Chantilly, VA  75000.0
# 52                                   McLean, VA 22102  75000.0
# 53                                     Alexandria, VA  75000.0
# 54                                         Reston, VA  75000.0
# 55                                         Reston, VA  75000.0
# 56                                         Reston, VA  75000.0
# 57                                         Reston, VA  75000.0
#
#              Title   Experience
# 0   Data_Scientist  Entry_level
# 1   Data_Scientist  Entry_level
# 2   Data_Scientist  Entry_level
# 3   Data_Scientist  Entry_level
# 4   Data_Scientist  Entry_level
# 5   Data_Scientist  Entry_level
# 6   Data_Scientist  Entry_level
# 7   Data_Scientist  Entry_level
# 8   Data_Scientist  Entry_level
# 9   Data_Scientist  Entry_level
# 10  Data_Scientist  Entry_level
# 11  Data_Scientist  Entry_level
# 12  Data_Scientist  Entry_level
# 13  Data_Scientist  Entry_level
# 14  Data_Scientist  Entry_level
# 15  Data_Scientist  Entry_level
# 16  Data_Scientist  Entry_level
# 17  Data_Scientist  Entry_level
# 18  Data_Scientist  Entry_level
# 19  Data_Scientist  Entry_level
# 20  Data_Scientist  Entry_level
# 21  Data_Scientist  Entry_level
# 22  Data_Scientist  Entry_level
# 23  Data_Scientist  Entry_level
# 24  Data_Scientist  Entry_level
# 25  Data_Scientist  Entry_level
# 26  Data_Scientist  Entry_level
# 27  Data_Scientist  Entry_level
# 28  Data_Scientist  Entry_level
# 29  Data_Scientist  Entry_level
# 30  Data_Scientist  Entry_level
# 31  Data_Scientist  Entry_level
# 32  Data_Scientist  Entry_level
# 33  Data_Scientist  Entry_level
# 34  Data_Scientist  Entry_level
# 35  Data_Scientist  Entry_level
# 36  Data_Scientist  Entry_level
# 37  Data_Scientist  Entry_level
# 38  Data_Scientist  Entry_level
# 39  Data_Scientist  Entry_level
# 40  Data_Scientist  Entry_level
# 41  Data_Scientist  Entry_level
# 42  Data_Scientist  Entry_level
# 43  Data_Scientist  Entry_level
# 44  Data_Scientist  Entry_level
# 45  Data_Scientist  Entry_level
# 46  Data_Scientist  Entry_level
# 47  Data_Scientist  Entry_level
# 48  Data_Scientist  Entry_level
# 49  Data_Scientist  Entry_level
# 50  Data_Scientist  Entry_level
# 51  Data_Scientist  Entry_level
# 52  Data_Scientist  Entry_level
# 53  Data_Scientist  Entry_level
# 54  Data_Scientist  Entry_level
# 55  Data_Scientist  Entry_level
# 56  Data_Scientist  Entry_level
# 57  Data_Scientist  Entry_level

# %%
result_SF_140_senior.head()
# Out:
#              Company_name                                        Location  \
# 0                   Hired                               San Francisco, CA
# 1               Sigmaways                                   Palo Alto, CA
# 2              Change.org  San Francisco, CA 94103 (South Of Market area)
# 3              TEKsystems  San Francisco, CA 94103 (South Of Market area)
# 4      Gap Inc. Corporate                               San Francisco, CA
#
#      Salary           Title    Experience
# 0  140000.0  Data_Scientist  Senior_level
# 1  140000.0  Data_Scientist  Senior_level
# 2  140000.0  Data_Scientist  Senior_level
# 3  140000.0  Data_Scientist  Senior_level
# 4  140000.0  Data_Scientist  Senior_level

# %% [markdown]
# ## Data_scientist_DC_75_mid

# %%
driver = webdriver.Chrome()
url = "https://www.indeed.com/jobs?q=%22Data+Scientist%22+$75,000&l=%22Washington,+DC%22&radius=100&explvl=mid_level&limit=100"
driver.get(url)
# wait one second
sleep(1)
#grab the page source
html = driver.page_source
# BeautifulSoup it!
html = BeautifulSoup(html)
driver.close()

# I'm going to create my empty df first
import pandas as pd
dcarea_job1 = pd.DataFrame(columns=["Company_name"])
dcarea_job2 = pd.DataFrame(columns=["Location","Salary", "Title","Experience"])
# loop through each entry
for company in html.find_all('span', {'class':'company'}):
    name_comp = company.text
    dcarea_job1.loc[len(dcarea_job1)]=[name_comp]
    
for location in html.find_all('span', {'class':'location'}):
    loc_comp = location.text
    salary = 75000
    experience = "Mid_level"
    # try to find the number of bookings
    title = "Data_Scientist"
    dcarea_job2.loc[len(dcarea_job2)]=[loc_comp,salary,title,experience]

dcarea_job1['Company_name'] = dcarea_job1['Company_name'].str.replace('\n', '')
dcarea_job2['Location'] = dcarea_job2['Location'].str.replace('\n', '')

result_DC_75_mid = pd.concat([dcarea_job1, dcarea_job2], axis=1)

result_DC_75_mid
# Out:
#                                           Company_name  \
# 0                                The Verity Group, LLC
# 1                                          DataLab USA
# 2               All Things Considered Staffing (ATC-S)
# 3                                   Excella Consulting
# 4                                  Booz Allen Hamilton
# 5                                              xometry
# 6                                              Verizon
# 7                                           Barbaricum
# 8                                        Deutsche Bank
# 9                         Applied Information Sciences
# 10                                                CACI
# 11                                             Agilent
# 12                                    Oscar Technology
# 13               University of Maryland Medical System
# 14                                   Centra Technology
# 15                                             Novetta
# 16                                        ASRC Federal
# 17                                           DataRobot
# 18                                             Vencore
# 19           The Johns Hopkins Applied Physics Labo...
# 20                                            QxBranch
# 21                                                KPMG
# 22                                             Novetta
# 23                         Information Innovators Inc.
# 24                                                CAVA
# 25                      Applied Communication Sciences
# 26               American Society of Clinical Oncology
# 27                                 Booz Allen Hamilton
# 28                                         TransVoyant
# 29                                              Leidos
# ..                                                 ...
# 75                                     PureIntegration
# 76                                         Capital One
# 77                                    Apex Systems Inc
# 78                                        Reperio Inc.
# 79                                            In-Q-Tel
# 80                                         Capital One
# 81                            Digital Management, Inc.
# 82                                         Capital One
# 83                                         Capital One
# 84                                  Praxis Engineering
# 85                                            Coverent
# 86                                 The Stratagem Group
# 87                                             Vencore
# 88                                Engility Corporation
# 89                               The Verity Group, LLC
# 90                                                CAVA
# 91                                         Merkle Inc.
# 92                            The Wallach Search Group
# 93                                      WhiteHawk Inc.
# 94                                    All-In Analytics
# 95                                                ERPi
# 96                                         Capital One
# 97                                            Zoomdata
# 98                                   Mitre Corporation
# 99                                             Socrata
# 100                                        Capital One
# 101                                      Bluehawk, LLC
# 102                                           Zoomdata
# 103                               Engility Corporation
# 104                     The Upside Travel Company, LLC
#
#                                           Location   Salary           Title  \
# 0                                   Alexandria, VA  75000.0  Data_Scientist
# 1                             Germantown, MD 20876  75000.0  Data_Scientist
# 2                                   Washington, DC  75000.0  Data_Scientist
# 3         Washington, DC 20006 (Foggy Bottom area)  75000.0  Data_Scientist
# 4                                   Washington, DC  75000.0  Data_Scientist
# 5                                     Bethesda, MD  75000.0  Data_Scientist
# 6                          Silver Spring, MD 20904  75000.0  Data_Scientist
# 7                                   Washington, DC  75000.0  Data_Scientist
# 8                                   Washington, DC  75000.0  Data_Scientist
# 9                                   Washington, DC  75000.0  Data_Scientist
# 10     Charlottesville, VA 22909 (North East area)  75000.0  Data_Scientist
# 11                                  Wilmington, DE  75000.0  Data_Scientist
# 12                                   Baltimore, MD  75000.0  Data_Scientist
# 13                     Linthicum Heights, MD 21090  75000.0  Data_Scientist
# 14                                   Arlington, VA  75000.0  Data_Scientist
# 15                                Crystal City, VA  75000.0  Data_Scientist
# 16                                  Alexandria, VA  75000.0  Data_Scientist
# 17                                  Washington, DC  75000.0  Data_Scientist
# 18                                      McLean, VA  75000.0  Data_Scientist
# 19                                      Laurel, MD  75000.0  Data_Scientist
# 20                                  Washington, DC  75000.0  Data_Scientist
# 21            Washington, DC 20036 (Downtown area)  75000.0  Data_Scientist
# 22                                 Springfield, VA  75000.0  Data_Scientist
# 23                                  Alexandria, VA  75000.0  Data_Scientist
# 24   Washington, DC 20009 (U Street Corridor area)  75000.0  Data_Scientist
# 25                                  Washington, DC  75000.0  Data_Scientist
# 26                                  Alexandria, VA  75000.0  Data_Scientist
# 27                                  Alexandria, VA  75000.0  Data_Scientist
# 28                            Alexandria, VA 22303  75000.0  Data_Scientist
# 29                                Reston, VA 20191  75000.0  Data_Scientist
# ..                                             ...      ...             ...
# 75                                      Dulles, VA  75000.0  Data_Scientist
# 76                                      McLean, VA  75000.0  Data_Scientist
# 77                             Charlottesville, VA  75000.0  Data_Scientist
# 78        Washington, DC 20005 (Logan Circle area)  75000.0  Data_Scientist
# 79         Arlington, VA 22201 (Lyon Village area)  75000.0  Data_Scientist
# 80                                      Vienna, VA  75000.0  Data_Scientist
# 81                              Lexington Park, MD  75000.0  Data_Scientist
# 82                                      McLean, VA  75000.0  Data_Scientist
# 83                                      McLean, VA  75000.0  Data_Scientist
# 84                                      Reston, VA  75000.0  Data_Scientist
# 85                                      Reston, VA  75000.0  Data_Scientist
# 86                                  Alexandria, VA  75000.0  Data_Scientist
# 87                               Silver Spring, MD  75000.0  Data_Scientist
# 88                                Reston, VA 20191  75000.0  Data_Scientist
# 89                                  Alexandria, VA  75000.0  Data_Scientist
# 90   Washington, DC 20009 (U Street Corridor area)  75000.0  Data_Scientist
# 91                              Columbia, MD 21046  75000.0  Data_Scientist
# 92                                  Washington, DC  75000.0  Data_Scientist
# 93                                   Baltimore, MD  75000.0  Data_Scientist
# 94                                  Washington, DC  75000.0  Data_Scientist
# 95                                  Washington, DC  75000.0  Data_Scientist
# 96                                      Vienna, VA  75000.0  Data_Scientist
# 97                                      Reston, VA  75000.0  Data_Scientist
# 98                    Annapolis Junction, MD 20701  75000.0  Data_Scientist
# 99                                  Washington, DC  75000.0  Data_Scientist
# 100                                     McLean, VA  75000.0  Data_Scientist
# 101                                 Alexandria, VA  75000.0  Data_Scientist
# 102                                     Reston, VA  75000.0  Data_Scientist
# 103                               Reston, VA 20191  75000.0  Data_Scientist
# 104                                 Washington, DC  75000.0  Data_Scientist
#
#     Experience
# 0    Mid_level
# 1    Mid_level
# 2    Mid_level
# 3    Mid_level
# 4    Mid_level
# 5    Mid_level
# 6    Mid_level
# 7    Mid_level
# 8    Mid_level
# 9    Mid_level
# 10   Mid_level
# 11   Mid_level
# 12   Mid_level
# 13   Mid_level
# 14   Mid_level
# 15   Mid_level
# 16   Mid_level
# 17   Mid_level
# 18   Mid_level
# 19   Mid_level
# 20   Mid_level
# 21   Mid_level
# 22   Mid_level
# 23   Mid_level
# 24   Mid_level
# 25   Mid_level
# 26   Mid_level
# 27   Mid_level
# 28   Mid_level
# 29   Mid_level
# ..         ...
# 75   Mid_level
# 76   Mid_level
# 77   Mid_level
# 78   Mid_level
# 79   Mid_level
# 80   Mid_level
# 81   Mid_level
# 82   Mid_level
# 83   Mid_level
# 84   Mid_level
# 85   Mid_level
# 86   Mid_level
# 87   Mid_level
# 88   Mid_level
# 89   Mid_level
# 90   Mid_level
# 91   Mid_level
# 92   Mid_level
# 93   Mid_level
# 94   Mid_level
# 95   Mid_level
# 96   Mid_level
# 97   Mid_level
# 98   Mid_level
# 99   Mid_level
# 100  Mid_level
# 101  Mid_level
# 102  Mid_level
# 103  Mid_level
# 104  Mid_level
#
# [105 rows x 5 columns]

# %% [markdown]
# ## Data_scientist_DC_75_senior

# %%
driver = webdriver.Chrome()
url = "https://www.indeed.com/jobs?q=%22Data+Scientist%22+$75,000&l=%22Washington,+DC%22&radius=100&explvl=senior_level&limit=100"
driver.get(url)
# wait one second
sleep(1)
#grab the page source
html = driver.page_source
# BeautifulSoup it!
html = BeautifulSoup(html)
driver.close()

# I'm going to create my empty df first
import pandas as pd
dcarea_job1 = pd.DataFrame(columns=["Company_name"])
dcarea_job2 = pd.DataFrame(columns=["Location","Salary", "Title","Experience"])
# loop through each entry
for company in html.find_all('span', {'class':'company'}):
    name_comp = company.text
    dcarea_job1.loc[len(dcarea_job1)]=[name_comp]
    
for location in html.find_all('span', {'class':'location'}):
    loc_comp = location.text
    salary = 75000
    experience = "Senior_level"
    # try to find the number of bookings
    title = "Data_Scientist"
    dcarea_job2.loc[len(dcarea_job2)]=[loc_comp,salary,title,experience]

dcarea_job1['Company_name'] = dcarea_job1['Company_name'].str.replace('\n', '')
dcarea_job2['Location'] = dcarea_job2['Location'].str.replace('\n', '')

result_DC_75_senior = pd.concat([dcarea_job1, dcarea_job2], axis=1)

result_DC_75_senior
# Out:
#                                  Company_name  \
# 0                                QuintilesIMS
# 1                                     TD Bank
# 2                                      Leidos
# 3                  PricewaterhouseCoopers LLC
# 4                                       IMTAS
# 5                 Information Innovators Inc.
# 6                           Cubic Corporation
# 7                                        ITDC
# 8                         Booz Allen Hamilton
# 9                                     Vencore
# 10                        Booz Allen Hamilton
# 11             Applied Communication Sciences
# 12                        Booz Allen Hamilton
# 13                        Booz Allen Hamilton
# 14                  The Aerospace Corporation
# 15                          SnagAJob.com, Inc
# 16                    TechGuard Security, LLC
# 17                        Booz Allen Hamilton
# 18                              Knowesis Inc.
# 19                                     Leidos
# 20                                       CACI
# 21                                     Lotame
# 22                                     Leidos
# 23                                    Vencore
# 24                          Mitre Corporation
# 25                        Booz Allen Hamilton
# 26                       Technica Corporation
# 27                    Apogee Integration, LLC
# 28                               SapientNitro
# 29                                  ByteCubed
# 30                                     Alqimi
# 31                                BAE Systems
# 32                     Encore Search Partners
# 33                    Arch Capital Group Ltd.
# 34                         Praxis Engineering
# 35                           Seneca Resources
# 36                   OnPoint Consulting, Inc.
# 37                                        EXL
# 38                                Capital One
# 39                             Knowledge Link
# 40                           Apex Systems Inc
# 41                                    Vencore
# 42                                    Fulcrum
# 43                          Mitre Corporation
# 44                             TechMatrixInc.
# 45          Altamira Technologies Corporation
# 46                                        SC3
# 47                          EOIR Technologies
# 48                         Praxis Engineering
# 49                                       CCRi
# 50                                      TEGNA
# 51       Commonwealth Computer Research, Inc.
# 52                          EOIR Technologies
# 53                                   Deloitte
# 54                                   Zoomdata
# 55                                   Deloitte
# 56                                 System One
#
#                                              Location   Salary  \
# 0                                    Collegeville, PA  75000.0
# 1                                    Mount Laurel, NJ  75000.0
# 2                                      Washington, DC  75000.0
# 3                    Washington, DC 20001 (Shaw area)  75000.0
# 4                    Washington, DC 20001 (Shaw area)  75000.0
# 5                                      Washington, DC  75000.0
# 6                                       Arlington, VA  75000.0
# 7                                      Washington, DC  75000.0
# 8                                      Washington, DC  75000.0
# 9                                          McLean, VA  75000.0
# 10                                     Washington, DC  75000.0
# 11                                   College Park, MD  75000.0
# 12                                     Alexandria, VA  75000.0
# 13                                     Alexandria, VA  75000.0
# 14                                   Crystal City, VA  75000.0
# 15            Arlington, VA 22201 (Lyon Village area)  75000.0
# 16                                    Springfield, VA  75000.0
# 17                                         McLean, VA  75000.0
# 18            Arlington, VA 22201 (Lyon Village area)  75000.0
# 19                              Springfield, VA 22151  75000.0
# 20        Charlottesville, VA 22909 (North East area)  75000.0
# 21                                 Columbia, MD 21045  75000.0
# 22                                    Springfield, VA  75000.0
# 23                                   College Park, MD  75000.0
# 24                                       Bethesda, MD  75000.0
# 25                                     Alexandria, VA  75000.0
# 26                                         Dulles, VA  75000.0
# 27                                         Reston, VA  75000.0
# 28                                      Arlington, VA  75000.0
# 29                                      Arlington, VA  75000.0
# 30                                     Washington, DC  75000.0
# 31                                   Reston, VA 20191  75000.0
# 32                                         Reston, VA  75000.0
# 33                                     Washington, DC  75000.0
# 34                                         Reston, VA  75000.0
# 35                                      Arlington, VA  75000.0
# 36                                      Arlington, VA  75000.0
# 37                                     Wilmington, DE  75000.0
# 38                                     Wilmington, DE  75000.0
# 39                                      Chantilly, VA  75000.0
# 40                                       Columbia, MD  75000.0
# 41                                  Silver Spring, MD  75000.0
# 42                                         Reston, VA  75000.0
# 43                       Annapolis Junction, MD 20701  75000.0
# 44                                     Harrisburg, PA  75000.0
# 45                                      Chantilly, VA  75000.0
# 46                                        Fairfax, VA  75000.0
# 47                              Springfield, VA 22150  75000.0
# 48                                         Reston, VA  75000.0
# 49                                      Chantilly, VA  75000.0
# 50                                         McLean, VA  75000.0
# 51                                      Chantilly, VA  75000.0
# 52                              Springfield, VA 22150  75000.0
# 53  Arlington, VA 22209 (Radnor-Ft Myer Heights area)  75000.0
# 54                                         Reston, VA  75000.0
# 55                                Arlington, VA 22209  75000.0
# 56                                         Reston, VA  75000.0
#
#              Title    Experience
# 0   Data_Scientist  Senior_level
# 1   Data_Scientist  Senior_level
# 2   Data_Scientist  Senior_level
# 3   Data_Scientist  Senior_level
# 4   Data_Scientist  Senior_level
# 5   Data_Scientist  Senior_level
# 6   Data_Scientist  Senior_level
# 7   Data_Scientist  Senior_level
# 8   Data_Scientist  Senior_level
# 9   Data_Scientist  Senior_level
# 10  Data_Scientist  Senior_level
# 11  Data_Scientist  Senior_level
# 12  Data_Scientist  Senior_level
# 13  Data_Scientist  Senior_level
# 14  Data_Scientist  Senior_level
# 15  Data_Scientist  Senior_level
# 16  Data_Scientist  Senior_level
# 17  Data_Scientist  Senior_level
# 18  Data_Scientist  Senior_level
# 19  Data_Scientist  Senior_level
# 20  Data_Scientist  Senior_level
# 21  Data_Scientist  Senior_level
# 22  Data_Scientist  Senior_level
# 23  Data_Scientist  Senior_level
# 24  Data_Scientist  Senior_level
# 25  Data_Scientist  Senior_level
# 26  Data_Scientist  Senior_level
# 27  Data_Scientist  Senior_level
# 28  Data_Scientist  Senior_level
# 29  Data_Scientist  Senior_level
# 30  Data_Scientist  Senior_level
# 31  Data_Scientist  Senior_level
# 32  Data_Scientist  Senior_level
# 33  Data_Scientist  Senior_level
# 34  Data_Scientist  Senior_level
# 35  Data_Scientist  Senior_level
# 36  Data_Scientist  Senior_level
# 37  Data_Scientist  Senior_level
# 38  Data_Scientist  Senior_level
# 39  Data_Scientist  Senior_level
# 40  Data_Scientist  Senior_level
# 41  Data_Scientist  Senior_level
# 42  Data_Scientist  Senior_level
# 43  Data_Scientist  Senior_level
# 44  Data_Scientist  Senior_level
# 45  Data_Scientist  Senior_level
# 46  Data_Scientist  Senior_level
# 47  Data_Scientist  Senior_level
# 48  Data_Scientist  Senior_level
# 49  Data_Scientist  Senior_level
# 50  Data_Scientist  Senior_level
# 51  Data_Scientist  Senior_level
# 52  Data_Scientist  Senior_level
# 53  Data_Scientist  Senior_level
# 54  Data_Scientist  Senior_level
# 55  Data_Scientist  Senior_level
# 56  Data_Scientist  Senior_level

# %% [markdown]
# ## Data_scientist_DC_90_entry

# %%
driver = webdriver.Chrome()
url = "https://www.indeed.com/jobs?q=%22Data+Scientist%22+$90,000&l=%22Washington,+DC%22&radius=100&explvl=entry_level&limit=100"
driver.get(url)
# wait one second
sleep(1)
#grab the page source
html = driver.page_source
# BeautifulSoup it!
html = BeautifulSoup(html)
driver.close()

# I'm going to create my empty df first
import pandas as pd
dcarea_job1 = pd.DataFrame(columns=["Company_name"])
dcarea_job2 = pd.DataFrame(columns=["Location","Salary", "Title","Experience"])
# loop through each entry
for company in html.find_all('span', {'class':'company'}):
    name_comp = company.text
    dcarea_job1.loc[len(dcarea_job1)]=[name_comp]
    
for location in html.find_all('span', {'class':'location'}):
    loc_comp = location.text
    salary = 90000
    experience = "Entry_level"
    # try to find the number of bookings
    title = "Data_Scientist"
    dcarea_job2.loc[len(dcarea_job2)]=[loc_comp,salary,title,experience]

dcarea_job1['Company_name'] = dcarea_job1['Company_name'].str.replace('\n', '')
dcarea_job2['Location'] = dcarea_job2['Location'].str.replace('\n', '')

result_DC_90_entry = pd.concat([dcarea_job1, dcarea_job2], axis=1)

result_DC_90_entry
# Out:
#                                          Company_name  \
# 0                                  Predictive Science
# 1                                Engility Corporation
# 2           Massachusetts Institute of Technology ...
# 3                                 Booz Allen Hamilton
# 4                                 Booz Allen Hamilton
# 5                                 Booz Allen Hamilton
# 6                                           Vox Media
# 7                                 Booz Allen Hamilton
# 8                                 Booz Allen Hamilton
# 9                                 Booz Allen Hamilton
# 10                                 Gryphon Scientific
# 11                                 Jobspring Partners
# 12                                               SAIC
# 13                                               CACI
# 14                                    Lockheed Martin
# 15                                  Cubic Corporation
# 16                          Trinity Global Consulting
# 17                               Engility Corporation
# 18                                  Next Step Systems
# 19                                Booz Allen Hamilton
# 20                                               CCRi
# 21           Veteran Staffing Network of Easter Seals
# 22                    Whiteboard Federal Technologies
# 23                                SRL TotalSource LLC
# 24                             Encore Search Partners
# 25                                  Mitre Corporation
# 26                      Systems & Technology Research
# 27                                       AboutWeb LLC
# 28                                     WhiteHawk Inc.
# 29                     Logistics Management Institute
# 30                                            Bechtel
# 31                                        ROI Checker
# 32                                 Jobspring Partners
# 33               Commonwealth Computer Research, Inc.
# 34                                Berico Technologies
# 35                                        Capital One
# 36                     Synchronoss Technologies, Inc.
# 37                                Booz Allen Hamilton
# 38                                Sphere of Influence
# 39                                   All-In Analytics
# 40                    Whiteboard Federal Technologies
# 41                                Sphere of Influence
# 42                                     Selby Jennings
# 43                                           Zoomdata
#
#                                      Location   Salary           Title  \
# 0                               United States  90000.0  Data_Scientist
# 1                          Bethesda, MD 20892  90000.0  Data_Scientist
# 2                                 Provost, VA  90000.0  Data_Scientist
# 3                              Washington, DC  90000.0  Data_Scientist
# 4                              Washington, DC  90000.0  Data_Scientist
# 5                              Alexandria, VA  90000.0  Data_Scientist
# 6                              Washington, DC  90000.0  Data_Scientist
# 7                              Alexandria, VA  90000.0  Data_Scientist
# 8                         Chantilly, VA 20151  90000.0  Data_Scientist
# 9                                  McLean, VA  90000.0  Data_Scientist
# 10                            Takoma Park, MD  90000.0  Data_Scientist
# 11   Washington, DC 20005 (Logan Circle area)  90000.0  Data_Scientist
# 12                                 McLean, VA  90000.0  Data_Scientist
# 13           Washington, DC 20001 (Shaw area)  90000.0  Data_Scientist
# 14                              Rockville, MD  90000.0  Data_Scientist
# 15                              Tidewater, VA  90000.0  Data_Scientist
# 16                            Springfield, VA  90000.0  Data_Scientist
# 17                         Bethesda, MD 20892  90000.0  Data_Scientist
# 18                             Washington, DC  90000.0  Data_Scientist
# 19                                 McLean, VA  90000.0  Data_Scientist
# 20                        Charlottesville, VA  90000.0  Data_Scientist
# 21                                 McLean, VA  90000.0  Data_Scientist
# 22                                Herndon, VA  90000.0  Data_Scientist
# 23                             Washington, DC  90000.0  Data_Scientist
# 24                                 Reston, VA  90000.0  Data_Scientist
# 25                                 McLean, VA  90000.0  Data_Scientist
# 26        Arlington, VA 22203 (Bluemont area)  90000.0  Data_Scientist
# 27                           Vienna, VA 22182  90000.0  Data_Scientist
# 28                              Baltimore, MD  90000.0  Data_Scientist
# 29                                 McLean, VA  90000.0  Data_Scientist
# 30                                 Reston, VA  90000.0  Data_Scientist
# 31                           Vienna, VA 22180  90000.0  Data_Scientist
# 32                                 McLean, VA  90000.0  Data_Scientist
# 33  Charlottesville, VA 22901 (29 North area)  90000.0  Data_Scientist
# 34                           Gaithersburg, MD  90000.0  Data_Scientist
# 35                                 McLean, VA  90000.0  Data_Scientist
# 36                                 Reston, VA  90000.0  Data_Scientist
# 37                             Alexandria, VA  90000.0  Data_Scientist
# 38                                 McLean, VA  90000.0  Data_Scientist
# 39                             Washington, DC  90000.0  Data_Scientist
# 40                              Chantilly, VA  90000.0  Data_Scientist
# 41                           McLean, VA 22102  90000.0  Data_Scientist
# 42                             Alexandria, VA  90000.0  Data_Scientist
# 43                                 Reston, VA  90000.0  Data_Scientist
#
#      Experience
# 0   Entry_level
# 1   Entry_level
# 2   Entry_level
# 3   Entry_level
# 4   Entry_level
# 5   Entry_level
# 6   Entry_level
# 7   Entry_level
# 8   Entry_level
# 9   Entry_level
# 10  Entry_level
# 11  Entry_level
# 12  Entry_level
# 13  Entry_level
# 14  Entry_level
# 15  Entry_level
# 16  Entry_level
# 17  Entry_level
# 18  Entry_level
# 19  Entry_level
# 20  Entry_level
# 21  Entry_level
# 22  Entry_level
# 23  Entry_level
# 24  Entry_level
# 25  Entry_level
# 26  Entry_level
# 27  Entry_level
# 28  Entry_level
# 29  Entry_level
# 30  Entry_level
# 31  Entry_level
# 32  Entry_level
# 33  Entry_level
# 34  Entry_level
# 35  Entry_level
# 36  Entry_level
# 37  Entry_level
# 38  Entry_level
# 39  Entry_level
# 40  Entry_level
# 41  Entry_level
# 42  Entry_level
# 43  Entry_level

# %% [markdown]
# ## Data_scientist_DC_90_mid

# %%
driver = webdriver.Chrome()
url = "https://www.indeed.com/jobs?q=%22Data+Scientist%22+$90,000&l=%22Washington,+DC%22&radius=100&explvl=mid_level&limit=100"
driver.get(url)
# wait one second
sleep(1)
#grab the page source
html = driver.page_source
# BeautifulSoup it!
html = BeautifulSoup(html)
driver.close()

# I'm going to create my empty df first
import pandas as pd
dcarea_job1 = pd.DataFrame(columns=["Company_name"])
dcarea_job2 = pd.DataFrame(columns=["Location","Salary", "Title","Experience"])
# loop through each entry
for company in html.find_all('span', {'class':'company'}):
    name_comp = company.text
    dcarea_job1.loc[len(dcarea_job1)]=[name_comp]
    
for location in html.find_all('span', {'class':'location'}):
    loc_comp = location.text
    salary = 90000
    experience = "Mid_level"
    # try to find the number of bookings
    title = "Data_Scientist"
    dcarea_job2.loc[len(dcarea_job2)]=[loc_comp,salary,title,experience]

dcarea_job1['Company_name'] = dcarea_job1['Company_name'].str.replace('\n', '')
dcarea_job2['Location'] = dcarea_job2['Location'].str.replace('\n', '')

result_DC_90_mid = pd.concat([dcarea_job1, dcarea_job2], axis=1)

result_DC_90_mid
# Out:
#                                          Company_name  \
# 0                               The Verity Group, LLC
# 1                                         DataLab USA
# 2              All Things Considered Staffing (ATC-S)
# 3                                  Excella Consulting
# 4                                 Booz Allen Hamilton
# 5                                             Verizon
# 6                                          Barbaricum
# 7                                       Deutsche Bank
# 8                        Applied Information Sciences
# 9                                             Agilent
# 10                                   Oscar Technology
# 11              University of Maryland Medical System
# 12                                  Centra Technology
# 13                                            Novetta
# 14                                       ASRC Federal
# 15                                          DataRobot
# 16                                            Vencore
# 17          The Johns Hopkins Applied Physics Labo...
# 18                                           QxBranch
# 19                                            Novetta
# 20                        Information Innovators Inc.
# 21                                               CAVA
# 22                     Applied Communication Sciences
# 23              American Society of Clinical Oncology
# 24                                Booz Allen Hamilton
# 25                                        TransVoyant
# 26                                       ASRC Federal
# 27                                The Nielsen Company
# 28                  Altamira Technologies Corporation
# 29                                    ISPA Technology
# ..                                                ...
# 62                               Engility Corporation
# 63                                            Socrata
# 64                                Booz Allen Hamilton
# 65                                    PureIntegration
# 66                                        Capital One
# 67                                   Apex Systems Inc
# 68                                       Reperio Inc.
# 69                                           In-Q-Tel
# 70                                        Capital One
# 71                                        Capital One
# 72                                        Capital One
# 73                                 Praxis Engineering
# 74                                           Coverent
# 75                                The Stratagem Group
# 76                                            Vencore
# 77                               Engility Corporation
# 78                              The Verity Group, LLC
# 79                                               CAVA
# 80                           The Wallach Search Group
# 81                                   All-In Analytics
# 82                                        Capital One
# 83                                           Zoomdata
# 84                                  Mitre Corporation
# 85                                            Socrata
# 86                                        Capital One
# 87                                      Bluehawk, LLC
# 88                                           Zoomdata
# 89                                           Zoomdata
# 90                               Engility Corporation
# 91                     The Upside Travel Company, LLC
#
#                                          Location   Salary           Title  \
# 0                                  Alexandria, VA  90000.0  Data_Scientist
# 1                            Germantown, MD 20876  90000.0  Data_Scientist
# 2                                  Washington, DC  90000.0  Data_Scientist
# 3        Washington, DC 20006 (Foggy Bottom area)  90000.0  Data_Scientist
# 4                                  Washington, DC  90000.0  Data_Scientist
# 5                         Silver Spring, MD 20904  90000.0  Data_Scientist
# 6                                  Washington, DC  90000.0  Data_Scientist
# 7                                  Washington, DC  90000.0  Data_Scientist
# 8                                  Washington, DC  90000.0  Data_Scientist
# 9                                  Wilmington, DE  90000.0  Data_Scientist
# 10                                  Baltimore, MD  90000.0  Data_Scientist
# 11                    Linthicum Heights, MD 21090  90000.0  Data_Scientist
# 12                                  Arlington, VA  90000.0  Data_Scientist
# 13                               Crystal City, VA  90000.0  Data_Scientist
# 14                                 Alexandria, VA  90000.0  Data_Scientist
# 15                                 Washington, DC  90000.0  Data_Scientist
# 16                                     McLean, VA  90000.0  Data_Scientist
# 17                                     Laurel, MD  90000.0  Data_Scientist
# 18                                 Washington, DC  90000.0  Data_Scientist
# 19                                Springfield, VA  90000.0  Data_Scientist
# 20                                 Alexandria, VA  90000.0  Data_Scientist
# 21  Washington, DC 20009 (U Street Corridor area)  90000.0  Data_Scientist
# 22                                 Washington, DC  90000.0  Data_Scientist
# 23                                 Alexandria, VA  90000.0  Data_Scientist
# 24                                 Alexandria, VA  90000.0  Data_Scientist
# 25                           Alexandria, VA 22303  90000.0  Data_Scientist
# 26                                 Alexandria, VA  90000.0  Data_Scientist
# 27                                   Columbia, MD  90000.0  Data_Scientist
# 28                                Springfield, VA  90000.0  Data_Scientist
# 29                                 Washington, DC  90000.0  Data_Scientist
# ..                                            ...      ...             ...
# 62                            Chantilly, VA 20151  90000.0  Data_Scientist
# 63                                 Washington, DC  90000.0  Data_Scientist
# 64                                     McLean, VA  90000.0  Data_Scientist
# 65                                     Dulles, VA  90000.0  Data_Scientist
# 66                                     McLean, VA  90000.0  Data_Scientist
# 67                            Charlottesville, VA  90000.0  Data_Scientist
# 68       Washington, DC 20005 (Logan Circle area)  90000.0  Data_Scientist
# 69        Arlington, VA 22201 (Lyon Village area)  90000.0  Data_Scientist
# 70                                     Vienna, VA  90000.0  Data_Scientist
# 71                                     McLean, VA  90000.0  Data_Scientist
# 72                                     McLean, VA  90000.0  Data_Scientist
# 73                                     Reston, VA  90000.0  Data_Scientist
# 74                                     Reston, VA  90000.0  Data_Scientist
# 75                                 Alexandria, VA  90000.0  Data_Scientist
# 76                              Silver Spring, MD  90000.0  Data_Scientist
# 77                               Reston, VA 20191  90000.0  Data_Scientist
# 78                                 Alexandria, VA  90000.0  Data_Scientist
# 79  Washington, DC 20009 (U Street Corridor area)  90000.0  Data_Scientist
# 80                                 Washington, DC  90000.0  Data_Scientist
# 81                                 Washington, DC  90000.0  Data_Scientist
# 82                                     Vienna, VA  90000.0  Data_Scientist
# 83                                     Reston, VA  90000.0  Data_Scientist
# 84                   Annapolis Junction, MD 20701  90000.0  Data_Scientist
# 85                                 Washington, DC  90000.0  Data_Scientist
# 86                                     McLean, VA  90000.0  Data_Scientist
# 87                                 Alexandria, VA  90000.0  Data_Scientist
# 88                                     Reston, VA  90000.0  Data_Scientist
# 89                                     Reston, VA  90000.0  Data_Scientist
# 90                               Reston, VA 20191  90000.0  Data_Scientist
# 91                                 Washington, DC  90000.0  Data_Scientist
#
#    Experience
# 0   Mid_level
# 1   Mid_level
# 2   Mid_level
# 3   Mid_level
# 4   Mid_level
# 5   Mid_level
# 6   Mid_level
# 7   Mid_level
# 8   Mid_level
# 9   Mid_level
# 10  Mid_level
# 11  Mid_level
# 12  Mid_level
# 13  Mid_level
# 14  Mid_level
# 15  Mid_level
# 16  Mid_level
# 17  Mid_level
# 18  Mid_level
# 19  Mid_level
# 20  Mid_level
# 21  Mid_level
# 22  Mid_level
# 23  Mid_level
# 24  Mid_level
# 25  Mid_level
# 26  Mid_level
# 27  Mid_level
# 28  Mid_level
# 29  Mid_level
# ..        ...
# 62  Mid_level
# 63  Mid_level
# 64  Mid_level
# 65  Mid_level
# 66  Mid_level
# 67  Mid_level
# 68  Mid_level
# 69  Mid_level
# 70  Mid_level
# 71  Mid_level
# 72  Mid_level
# 73  Mid_level
# 74  Mid_level
# 75  Mid_level
# 76  Mid_level
# 77  Mid_level
# 78  Mid_level
# 79  Mid_level
# 80  Mid_level
# 81  Mid_level
# 82  Mid_level
# 83  Mid_level
# 84  Mid_level
# 85  Mid_level
# 86  Mid_level
# 87  Mid_level
# 88  Mid_level
# 89  Mid_level
# 90  Mid_level
# 91  Mid_level
#
# [92 rows x 5 columns]

# %% [markdown]
# ## Data_scientist_DC_90_senior

# %%
driver = webdriver.Chrome()
url = "https://www.indeed.com/jobs?q=%22Data+Scientist%22+$90,000&l=%22Washington,+DC%22&radius=100&explvl=senior_level&limit=100"
driver.get(url)
# wait one second
sleep(1)
#grab the page source
html = driver.page_source
# BeautifulSoup it!
html = BeautifulSoup(html)
driver.close()

# I'm going to create my empty df first
import pandas as pd
dcarea_job1 = pd.DataFrame(columns=["Company_name"])
dcarea_job2 = pd.DataFrame(columns=["Location","Salary", "Title","Experience"])
# loop through each entry
for company in html.find_all('span', {'class':'company'}):
    name_comp = company.text
    dcarea_job1.loc[len(dcarea_job1)]=[name_comp]
    
for location in html.find_all('span', {'class':'location'}):
    loc_comp = location.text
    salary = 90000
    experience = "Senior_level"
    # try to find the number of bookings
    title = "Data_Scientist"
    dcarea_job2.loc[len(dcarea_job2)]=[loc_comp,salary,title,experience]

dcarea_job1['Company_name'] = dcarea_job1['Company_name'].str.replace('\n', '')
dcarea_job2['Location'] = dcarea_job2['Location'].str.replace('\n', '')

result_DC_90_senior = pd.concat([dcarea_job1, dcarea_job2], axis=1)

result_DC_90_senior
# Out:
#                                  Company_name  \
# 0                                QuintilesIMS
# 1                                  System One
# 2                                     TD Bank
# 3                                       IMTAS
# 4                 Information Innovators Inc.
# 5                                        ITDC
# 6                         Booz Allen Hamilton
# 7                                     Vencore
# 8                         Booz Allen Hamilton
# 9              Applied Communication Sciences
# 10                        Booz Allen Hamilton
# 11                        Booz Allen Hamilton
# 12                  The Aerospace Corporation
# 13                          SnagAJob.com, Inc
# 14                        Booz Allen Hamilton
# 15                              Knowesis Inc.
# 16                                       CACI
# 17                                     Lotame
# 18                                    Vencore
# 19                          Mitre Corporation
# 20                        Booz Allen Hamilton
# 21                       Technica Corporation
# 22                               SapientNitro
# 23                                  ByteCubed
# 24                                     Alqimi
# 25                                     Leidos
# 26                     Encore Search Partners
# 27                    Arch Capital Group Ltd.
# 28                         Praxis Engineering
# 29                   OnPoint Consulting, Inc.
# 30                                        EXL
# 31                                Capital One
# 32                           Apex Systems Inc
# 33                          Mitre Corporation
# 34                             TechMatrixInc.
# 35          Altamira Technologies Corporation
# 36                                        SC3
# 37                          EOIR Technologies
# 38                         Praxis Engineering
# 39                                       CCRi
# 40       Commonwealth Computer Research, Inc.
# 41                          EOIR Technologies
# 42                                   Zoomdata
# 43                                     Leidos
#
#                                        Location   Salary           Title  \
# 0                              Collegeville, PA  90000.0  Data_Scientist
# 1                                    Reston, VA  90000.0  Data_Scientist
# 2                              Mount Laurel, NJ  90000.0  Data_Scientist
# 3              Washington, DC 20001 (Shaw area)  90000.0  Data_Scientist
# 4                                Washington, DC  90000.0  Data_Scientist
# 5                                Washington, DC  90000.0  Data_Scientist
# 6                                Washington, DC  90000.0  Data_Scientist
# 7                                    McLean, VA  90000.0  Data_Scientist
# 8                                Washington, DC  90000.0  Data_Scientist
# 9                              College Park, MD  90000.0  Data_Scientist
# 10                               Alexandria, VA  90000.0  Data_Scientist
# 11                               Alexandria, VA  90000.0  Data_Scientist
# 12                             Crystal City, VA  90000.0  Data_Scientist
# 13      Arlington, VA 22201 (Lyon Village area)  90000.0  Data_Scientist
# 14                                   McLean, VA  90000.0  Data_Scientist
# 15      Arlington, VA 22201 (Lyon Village area)  90000.0  Data_Scientist
# 16  Charlottesville, VA 22909 (North East area)  90000.0  Data_Scientist
# 17                           Columbia, MD 21045  90000.0  Data_Scientist
# 18                             College Park, MD  90000.0  Data_Scientist
# 19                                 Bethesda, MD  90000.0  Data_Scientist
# 20                               Alexandria, VA  90000.0  Data_Scientist
# 21                                   Dulles, VA  90000.0  Data_Scientist
# 22                                Arlington, VA  90000.0  Data_Scientist
# 23                                Arlington, VA  90000.0  Data_Scientist
# 24                               Washington, DC  90000.0  Data_Scientist
# 25             Washington, DC 20001 (Shaw area)  90000.0  Data_Scientist
# 26                                   Reston, VA  90000.0  Data_Scientist
# 27                               Washington, DC  90000.0  Data_Scientist
# 28                                   Reston, VA  90000.0  Data_Scientist
# 29                                Arlington, VA  90000.0  Data_Scientist
# 30                               Wilmington, DE  90000.0  Data_Scientist
# 31                               Wilmington, DE  90000.0  Data_Scientist
# 32                                 Columbia, MD  90000.0  Data_Scientist
# 33                 Annapolis Junction, MD 20701  90000.0  Data_Scientist
# 34                               Harrisburg, PA  90000.0  Data_Scientist
# 35                                Chantilly, VA  90000.0  Data_Scientist
# 36                                  Fairfax, VA  90000.0  Data_Scientist
# 37                        Springfield, VA 22150  90000.0  Data_Scientist
# 38                                   Reston, VA  90000.0  Data_Scientist
# 39                                Chantilly, VA  90000.0  Data_Scientist
# 40                                Chantilly, VA  90000.0  Data_Scientist
# 41                        Springfield, VA 22150  90000.0  Data_Scientist
# 42                                   Reston, VA  90000.0  Data_Scientist
# 43                               Washington, DC  90000.0  Data_Scientist
#
#       Experience
# 0   Senior_level
# 1   Senior_level
# 2   Senior_level
# 3   Senior_level
# 4   Senior_level
# 5   Senior_level
# 6   Senior_level
# 7   Senior_level
# 8   Senior_level
# 9   Senior_level
# 10  Senior_level
# 11  Senior_level
# 12  Senior_level
# 13  Senior_level
# 14  Senior_level
# 15  Senior_level
# 16  Senior_level
# 17  Senior_level
# 18  Senior_level
# 19  Senior_level
# 20  Senior_level
# 21  Senior_level
# 22  Senior_level
# 23  Senior_level
# 24  Senior_level
# 25  Senior_level
# 26  Senior_level
# 27  Senior_level
# 28  Senior_level
# 29  Senior_level
# 30  Senior_level
# 31  Senior_level
# 32  Senior_level
# 33  Senior_level
# 34  Senior_level
# 35  Senior_level
# 36  Senior_level
# 37  Senior_level
# 38  Senior_level
# 39  Senior_level
# 40  Senior_level
# 41  Senior_level
# 42  Senior_level
# 43  Senior_level

# %% [markdown]
# ## extra

# %%
df = pd.DataFrame({'Date': ['somedate', 'somedate'],
                   'location': ['united_kingdom_london', 'united_state_newyork'],
                   'occurence': [5, 5]})

# %%
df
# Out:
#        Date               location  occurence
# 0  somedate  united_kingdom_london          5
# 1  somedate   united_state_newyork          5

# %%
df['Country'] = df['location'].str.rpartition('_')[0].str.replace("_", " ")
df['City']    = df['location'].str.rpartition('_')[2]
df[['Date','Country', 'City', 'occurence']]
# Out:
#        Date         Country     City  occurence
# 0  somedate  united kingdom   london          5
# 1  somedate    united state  newyork          5

# %% [markdown]
# ## Data_scientist_DC_105_entry

# %%
driver = webdriver.Chrome()
url = "https://www.indeed.com/jobs?q=%22Data+Scientist%22+$105,000&l=%22Washington,+DC%22&radius=100&explvl=entry_level&limit=100"
driver.get(url)
# wait one second
sleep(1)
#grab the page source
html = driver.page_source
# BeautifulSoup it!
html = BeautifulSoup(html)
driver.close()

# I'm going to create my empty df first
import pandas as pd
dcarea_job1 = pd.DataFrame(columns=["Company_name"])
dcarea_job2 = pd.DataFrame(columns=["Location","Salary", "Title","Experience"])
# loop through each entry
for company in html.find_all('span', {'class':'company'}):
    name_comp = company.text
    dcarea_job1.loc[len(dcarea_job1)]=[name_comp]
    
for location in html.find_all('span', {'class':'location'}):
    loc_comp = location.text
    salary = 105000
    experience = "Entry_level"
    # try to find the number of bookings
    title = "Data_Scientist"
    dcarea_job2.loc[len(dcarea_job2)]=[loc_comp,salary,title,experience]

dcarea_job1['Company_name'] = dcarea_job1['Company_name'].str.replace('\n', '')
dcarea_job2['Location'] = dcarea_job2['Location'].str.replace('\n', '')

result_DC_105_entry = pd.concat([dcarea_job1, dcarea_job2], axis=1)

result_DC_105_entry
# Out:
#                                     Company_name  \
# 0                             Predictive Science
# 1                            Booz Allen Hamilton
# 2                            Booz Allen Hamilton
# 3                            Booz Allen Hamilton
# 4                                      Vox Media
# 5                            Booz Allen Hamilton
# 6                            Booz Allen Hamilton
# 7                             Jobspring Partners
# 8                                           SAIC
# 9                                           CACI
# 10                               Lockheed Martin
# 11                           Booz Allen Hamilton
# 12                                          CCRi
# 13      Veteran Staffing Network of Easter Seals
# 14               Whiteboard Federal Technologies
# 15                           SRL TotalSource LLC
# 16                        Encore Search Partners
# 17                             Mitre Corporation
# 18                 Systems & Technology Research
# 19                                WhiteHawk Inc.
# 20                                       Bechtel
# 21                            Jobspring Partners
# 22          Commonwealth Computer Research, Inc.
# 23                           Berico Technologies
# 24                Synchronoss Technologies, Inc.
# 25                           Booz Allen Hamilton
# 26                           Sphere of Influence
# 27                           Sphere of Influence
# 28                                Selby Jennings
# 29                                      Zoomdata
#
#                                      Location    Salary           Title  \
# 0                               United States  105000.0  Data_Scientist
# 1                              Washington, DC  105000.0  Data_Scientist
# 2                              Washington, DC  105000.0  Data_Scientist
# 3                              Alexandria, VA  105000.0  Data_Scientist
# 4                              Washington, DC  105000.0  Data_Scientist
# 5                         Chantilly, VA 20151  105000.0  Data_Scientist
# 6                                  McLean, VA  105000.0  Data_Scientist
# 7    Washington, DC 20005 (Logan Circle area)  105000.0  Data_Scientist
# 8                                  McLean, VA  105000.0  Data_Scientist
# 9            Washington, DC 20001 (Shaw area)  105000.0  Data_Scientist
# 10                              Rockville, MD  105000.0  Data_Scientist
# 11                                 McLean, VA  105000.0  Data_Scientist
# 12                        Charlottesville, VA  105000.0  Data_Scientist
# 13                                 McLean, VA  105000.0  Data_Scientist
# 14                                Herndon, VA  105000.0  Data_Scientist
# 15                             Washington, DC  105000.0  Data_Scientist
# 16                                 Reston, VA  105000.0  Data_Scientist
# 17                                 McLean, VA  105000.0  Data_Scientist
# 18        Arlington, VA 22203 (Bluemont area)  105000.0  Data_Scientist
# 19                              Baltimore, MD  105000.0  Data_Scientist
# 20                                 Reston, VA  105000.0  Data_Scientist
# 21                                 McLean, VA  105000.0  Data_Scientist
# 22  Charlottesville, VA 22901 (29 North area)  105000.0  Data_Scientist
# 23                           Gaithersburg, MD  105000.0  Data_Scientist
# 24                                 Reston, VA  105000.0  Data_Scientist
# 25                             Alexandria, VA  105000.0  Data_Scientist
# 26                                 McLean, VA  105000.0  Data_Scientist
# 27                           McLean, VA 22102  105000.0  Data_Scientist
# 28                             Alexandria, VA  105000.0  Data_Scientist
# 29                                 Reston, VA  105000.0  Data_Scientist
#
#      Experience
# 0   Entry_level
# 1   Entry_level
# 2   Entry_level
# 3   Entry_level
# 4   Entry_level
# 5   Entry_level
# 6   Entry_level
# 7   Entry_level
# 8   Entry_level
# 9   Entry_level
# 10  Entry_level
# 11  Entry_level
# 12  Entry_level
# 13  Entry_level
# 14  Entry_level
# 15  Entry_level
# 16  Entry_level
# 17  Entry_level
# 18  Entry_level
# 19  Entry_level
# 20  Entry_level
# 21  Entry_level
# 22  Entry_level
# 23  Entry_level
# 24  Entry_level
# 25  Entry_level
# 26  Entry_level
# 27  Entry_level
# 28  Entry_level
# 29  Entry_level

# %% [markdown]
# ## Data_scientist_DC_105_mid

# %%
driver = webdriver.Chrome()
url = "https://www.indeed.com/jobs?q=%22Data+Scientist%22+$105,000&l=%22Washington,+DC%22&radius=100&explvl=mid_level&limit=100"
driver.get(url)
# wait one second
sleep(1)
#grab the page source
html = driver.page_source
# BeautifulSoup it!
html = BeautifulSoup(html)
driver.close()

# I'm going to create my empty df first
import pandas as pd
dcarea_job1 = pd.DataFrame(columns=["Company_name"])
dcarea_job2 = pd.DataFrame(columns=["Location","Salary", "Title","Experience"])
# loop through each entry
for company in html.find_all('span', {'class':'company'}):
    name_comp = company.text
    dcarea_job1.loc[len(dcarea_job1)]=[name_comp]
    
for location in html.find_all('span', {'class':'location'}):
    loc_comp = location.text
    salary = 105000
    experience = "Mid_level"
    # try to find the number of bookings
    title = "Data_Scientist"
    dcarea_job2.loc[len(dcarea_job2)]=[loc_comp,salary,title,experience]

dcarea_job1['Company_name'] = dcarea_job1['Company_name'].str.replace('\n', '')
dcarea_job2['Location'] = dcarea_job2['Location'].str.replace('\n', '')

result_DC_105_mid = pd.concat([dcarea_job1, dcarea_job2], axis=1)

result_DC_105_mid
# Out:
#                                          Company_name  \
# 0                               The Verity Group, LLC
# 1              All Things Considered Staffing (ATC-S)
# 2                      Atrilogy Solutions Group, Inc.
# 3                                  Excella Consulting
# 4                                 Booz Allen Hamilton
# 5                                             Verizon
# 6                                          Barbaricum
# 7                                       Deutsche Bank
# 8                                    Oscar Technology
# 9                                             Novetta
# 10                                       ASRC Federal
# 11                                          DataRobot
# 12                                            Vencore
# 13          The Johns Hopkins Applied Physics Labo...
# 14                                            Novetta
# 15                                               CAVA
# 16              American Society of Clinical Oncology
# 17                                Booz Allen Hamilton
# 18                                        TransVoyant
# 19                                       ASRC Federal
# 20                  Altamira Technologies Corporation
# 21                                           Teradata
# 22                     The Upside Travel Company, LLC
# 23                                               ESNS
# 24            Creative Associates International, Inc.
# 25                                  Aquila Technology
# 26                                        TransVoyant
# 27                                         IHS Markit
# 28                                  Mitre Corporation
# 29                                           In-Q-Tel
# ..                                                ...
# 35                                        Capital One
# 36                                    Solebrity, Inc.
# 37                  Altamira Technologies Corporation
# 38                     S&P GLOBAL MARKET INTELLIGENCE
# 39                                               KPMG
# 40                                  Mitre Corporation
# 41                     Elite Technical Services, Inc.
# 42                       Strategic Staffing Solutions
# 43                               Engility Corporation
# 44                                    PureIntegration
# 45                                        Capital One
# 46                                   Apex Systems Inc
# 47                                        Capital One
# 48                                        Capital One
# 49                                        Capital One
# 50                                 Praxis Engineering
# 51                                The Stratagem Group
# 52                              The Verity Group, LLC
# 53                                               CAVA
# 54                           The Wallach Search Group
# 55                                   All-In Analytics
# 56                                        Capital One
# 57                                           Zoomdata
# 58                                  Mitre Corporation
# 59                                            Socrata
# 60                                        Capital One
# 61                                           Zoomdata
# 62                                           Zoomdata
# 63                             Randstad Professionals
# 64                     The Upside Travel Company, LLC
#
#                                          Location    Salary           Title  \
# 0                                  Alexandria, VA  105000.0  Data_Scientist
# 1                                  Washington, DC  105000.0  Data_Scientist
# 2                            Washington, DC 20001  105000.0  Data_Scientist
# 3        Washington, DC 20006 (Foggy Bottom area)  105000.0  Data_Scientist
# 4                                  Washington, DC  105000.0  Data_Scientist
# 5                         Silver Spring, MD 20904  105000.0  Data_Scientist
# 6                                  Washington, DC  105000.0  Data_Scientist
# 7                                  Washington, DC  105000.0  Data_Scientist
# 8                                   Baltimore, MD  105000.0  Data_Scientist
# 9                                Crystal City, VA  105000.0  Data_Scientist
# 10                                 Alexandria, VA  105000.0  Data_Scientist
# 11                                 Washington, DC  105000.0  Data_Scientist
# 12                                     McLean, VA  105000.0  Data_Scientist
# 13                                     Laurel, MD  105000.0  Data_Scientist
# 14                                Springfield, VA  105000.0  Data_Scientist
# 15  Washington, DC 20009 (U Street Corridor area)  105000.0  Data_Scientist
# 16                                 Alexandria, VA  105000.0  Data_Scientist
# 17                                 Alexandria, VA  105000.0  Data_Scientist
# 18                           Alexandria, VA 22303  105000.0  Data_Scientist
# 19                                 Alexandria, VA  105000.0  Data_Scientist
# 20                                Springfield, VA  105000.0  Data_Scientist
# 21                                 Washington, DC  105000.0  Data_Scientist
# 22                                 Washington, DC  105000.0  Data_Scientist
# 23                                    Herndon, VA  105000.0  Data_Scientist
# 24      Washington, DC 20015 (Barnaby Woods area)  105000.0  Data_Scientist
# 25                                Springfield, VA  105000.0  Data_Scientist
# 26                           Alexandria, VA 22303  105000.0  Data_Scientist
# 27                                 Washington, DC  105000.0  Data_Scientist
# 28         Washington, DC 20024 (South West area)  105000.0  Data_Scientist
# 29        Arlington, VA 22201 (Lyon Village area)  105000.0  Data_Scientist
# ..                                            ...       ...             ...
# 35                                     McLean, VA  105000.0  Data_Scientist
# 36                              Ashburn, VA 20147  105000.0  Data_Scientist
# 37                                  Chantilly, VA  105000.0  Data_Scientist
# 38    Charlottesville, VA 22909 (North East area)  105000.0  Data_Scientist
# 39           Washington, DC 20036 (Downtown area)  105000.0  Data_Scientist
# 40                                     McLean, VA  105000.0  Data_Scientist
# 41                                 Washington, DC  105000.0  Data_Scientist
# 42                                     McLean, VA  105000.0  Data_Scientist
# 43                            Chantilly, VA 20151  105000.0  Data_Scientist
# 44                                     Dulles, VA  105000.0  Data_Scientist
# 45                                     McLean, VA  105000.0  Data_Scientist
# 46                            Charlottesville, VA  105000.0  Data_Scientist
# 47                                     Vienna, VA  105000.0  Data_Scientist
# 48                                     McLean, VA  105000.0  Data_Scientist
# 49                                     McLean, VA  105000.0  Data_Scientist
# 50                                     Reston, VA  105000.0  Data_Scientist
# 51                                 Alexandria, VA  105000.0  Data_Scientist
# 52                                 Alexandria, VA  105000.0  Data_Scientist
# 53  Washington, DC 20009 (U Street Corridor area)  105000.0  Data_Scientist
# 54                                 Washington, DC  105000.0  Data_Scientist
# 55                                 Washington, DC  105000.0  Data_Scientist
# 56                                     Vienna, VA  105000.0  Data_Scientist
# 57                                     Reston, VA  105000.0  Data_Scientist
# 58                   Annapolis Junction, MD 20701  105000.0  Data_Scientist
# 59                                 Washington, DC  105000.0  Data_Scientist
# 60                                     McLean, VA  105000.0  Data_Scientist
# 61                                     Reston, VA  105000.0  Data_Scientist
# 62                                     Reston, VA  105000.0  Data_Scientist
# 63                             Bethesda, MD 20814  105000.0  Data_Scientist
# 64                                 Washington, DC  105000.0  Data_Scientist
#
#    Experience
# 0   Mid_level
# 1   Mid_level
# 2   Mid_level
# 3   Mid_level
# 4   Mid_level
# 5   Mid_level
# 6   Mid_level
# 7   Mid_level
# 8   Mid_level
# 9   Mid_level
# 10  Mid_level
# 11  Mid_level
# 12  Mid_level
# 13  Mid_level
# 14  Mid_level
# 15  Mid_level
# 16  Mid_level
# 17  Mid_level
# 18  Mid_level
# 19  Mid_level
# 20  Mid_level
# 21  Mid_level
# 22  Mid_level
# 23  Mid_level
# 24  Mid_level
# 25  Mid_level
# 26  Mid_level
# 27  Mid_level
# 28  Mid_level
# 29  Mid_level
# ..        ...
# 35  Mid_level
# 36  Mid_level
# 37  Mid_level
# 38  Mid_level
# 39  Mid_level
# 40  Mid_level
# 41  Mid_level
# 42  Mid_level
# 43  Mid_level
# 44  Mid_level
# 45  Mid_level
# 46  Mid_level
# 47  Mid_level
# 48  Mid_level
# 49  Mid_level
# 50  Mid_level
# 51  Mid_level
# 52  Mid_level
# 53  Mid_level
# 54  Mid_level
# 55  Mid_level
# 56  Mid_level
# 57  Mid_level
# 58  Mid_level
# 59  Mid_level
# 60  Mid_level
# 61  Mid_level
# 62  Mid_level
# 63  Mid_level
# 64  Mid_level
#
# [65 rows x 5 columns]

# %% [markdown]
# ## Data_scientist_DC_105_senior

# %%
driver = webdriver.Chrome()
url = "https://www.indeed.com/jobs?q=%22Data+Scientist%22+$105,000&l=%22Washington,+DC%22&radius=100&explvl=senior_level&limit=100"
driver.get(url)
# wait one second
sleep(1)
#grab the page source
html = driver.page_source
# BeautifulSoup it!
html = BeautifulSoup(html)
driver.close()

# I'm going to create my empty df first
import pandas as pd
dcarea_job1 = pd.DataFrame(columns=["Company_name"])
dcarea_job2 = pd.DataFrame(columns=["Location","Salary", "Title","Experience"])
# loop through each entry
for company in html.find_all('span', {'class':'company'}):
    name_comp = company.text
    dcarea_job1.loc[len(dcarea_job1)]=[name_comp]
    
for location in html.find_all('span', {'class':'location'}):
    loc_comp = location.text
    salary = 105000
    experience = "Senior_level"
    # try to find the number of bookings
    title = "Data_Scientist"
    dcarea_job2.loc[len(dcarea_job2)]=[loc_comp,salary,title,experience]

dcarea_job1['Company_name'] = dcarea_job1['Company_name'].str.replace('\n', '')
dcarea_job2['Location'] = dcarea_job2['Location'].str.replace('\n', '')

result_DC_105_senior = pd.concat([dcarea_job1, dcarea_job2], axis=1)

result_DC_105_senior
# Out:
#                                  Company_name  \
# 0                                QuintilesIMS
# 1                                  System One
# 2                                     TD Bank
# 3                                       IMTAS
# 4                                        ITDC
# 5                         Booz Allen Hamilton
# 6                                     Vencore
# 7                         Booz Allen Hamilton
# 8              Applied Communication Sciences
# 9                         Booz Allen Hamilton
# 10                        Booz Allen Hamilton
# 11                  The Aerospace Corporation
# 12                          SnagAJob.com, Inc
# 13                        Booz Allen Hamilton
# 14                                     Lotame
# 15                                    Vencore
# 16                          Mitre Corporation
# 17                        Booz Allen Hamilton
# 18                       Technica Corporation
# 19                               SapientNitro
# 20                                  ByteCubed
# 21                     Encore Search Partners
# 22                    Arch Capital Group Ltd.
# 23                         Praxis Engineering
# 24                   OnPoint Consulting, Inc.
# 25                                        EXL
# 26                                Capital One
# 27                          Mitre Corporation
# 28          Altamira Technologies Corporation
# 29                                        SC3
# 30                         Praxis Engineering
# 31                                       CCRi
# 32       Commonwealth Computer Research, Inc.
# 33                          EOIR Technologies
# 34                                   Zoomdata
#
#                                    Location    Salary           Title  \
# 0                          Collegeville, PA  105000.0  Data_Scientist
# 1                                Reston, VA  105000.0  Data_Scientist
# 2                          Mount Laurel, NJ  105000.0  Data_Scientist
# 3          Washington, DC 20001 (Shaw area)  105000.0  Data_Scientist
# 4                            Washington, DC  105000.0  Data_Scientist
# 5                            Washington, DC  105000.0  Data_Scientist
# 6                                McLean, VA  105000.0  Data_Scientist
# 7                            Washington, DC  105000.0  Data_Scientist
# 8                          College Park, MD  105000.0  Data_Scientist
# 9                            Alexandria, VA  105000.0  Data_Scientist
# 10                           Alexandria, VA  105000.0  Data_Scientist
# 11                         Crystal City, VA  105000.0  Data_Scientist
# 12  Arlington, VA 22201 (Lyon Village area)  105000.0  Data_Scientist
# 13                      Chantilly, VA 20151  105000.0  Data_Scientist
# 14                       Columbia, MD 21045  105000.0  Data_Scientist
# 15                         College Park, MD  105000.0  Data_Scientist
# 16                             Bethesda, MD  105000.0  Data_Scientist
# 17                           Alexandria, VA  105000.0  Data_Scientist
# 18                               Dulles, VA  105000.0  Data_Scientist
# 19                            Arlington, VA  105000.0  Data_Scientist
# 20                            Arlington, VA  105000.0  Data_Scientist
# 21                               Reston, VA  105000.0  Data_Scientist
# 22                           Washington, DC  105000.0  Data_Scientist
# 23                               Reston, VA  105000.0  Data_Scientist
# 24                            Arlington, VA  105000.0  Data_Scientist
# 25                           Wilmington, DE  105000.0  Data_Scientist
# 26                           Wilmington, DE  105000.0  Data_Scientist
# 27             Annapolis Junction, MD 20701  105000.0  Data_Scientist
# 28                            Chantilly, VA  105000.0  Data_Scientist
# 29                              Fairfax, VA  105000.0  Data_Scientist
# 30                               Reston, VA  105000.0  Data_Scientist
# 31                            Chantilly, VA  105000.0  Data_Scientist
# 32                            Chantilly, VA  105000.0  Data_Scientist
# 33                    Springfield, VA 22150  105000.0  Data_Scientist
# 34                               Reston, VA  105000.0  Data_Scientist
#
#       Experience
# 0   Senior_level
# 1   Senior_level
# 2   Senior_level
# 3   Senior_level
# 4   Senior_level
# 5   Senior_level
# 6   Senior_level
# 7   Senior_level
# 8   Senior_level
# 9   Senior_level
# 10  Senior_level
# 11  Senior_level
# 12  Senior_level
# 13  Senior_level
# 14  Senior_level
# 15  Senior_level
# 16  Senior_level
# 17  Senior_level
# 18  Senior_level
# 19  Senior_level
# 20  Senior_level
# 21  Senior_level
# 22  Senior_level
# 23  Senior_level
# 24  Senior_level
# 25  Senior_level
# 26  Senior_level
# 27  Senior_level
# 28  Senior_level
# 29  Senior_level
# 30  Senior_level
# 31  Senior_level
# 32  Senior_level
# 33  Senior_level
# 34  Senior_level

# %% [markdown]
# ## Data_scientist_DC_110_entry

# %%
driver = webdriver.Chrome()
url = "https://www.indeed.com/jobs?q=Data+Scientist+$110,000%2B&l=Washington,+DC&radius=100&explvl=entry_level&limit=100"
driver.get(url)
# wait one second
sleep(1)
#grab the page source
html = driver.page_source
# BeautifulSoup it!
html = BeautifulSoup(html)
driver.close()

# I'm going to create my empty df first
import pandas as pd
dcarea_job1 = pd.DataFrame(columns=["Company_name"])
dcarea_job2 = pd.DataFrame(columns=["Location","Salary", "Title","Experience"])
# loop through each entry
for company in html.find_all('span', {'class':'company'}):
    name_comp = company.text
    dcarea_job1.loc[len(dcarea_job1)]=[name_comp]
    
for location in html.find_all('span', {'class':'location'}):
    loc_comp = location.text
    salary = 110000
    experience = "Entry_level"
    # try to find the number of bookings
    title = "Data_Scientist"
    dcarea_job2.loc[len(dcarea_job2)]=[loc_comp,salary,title,experience]

dcarea_job1['Company_name'] = dcarea_job1['Company_name'].str.replace('\n', '')
dcarea_job2['Location'] = dcarea_job2['Location'].str.replace('\n', '')

result_DC_110_entry = pd.concat([dcarea_job1, dcarea_job2], axis=1)

result_DC_110_entry
# Out:
#                                          Company_name  \
# 0                                  Predictive Science
# 1                                 Liberty Information
# 2                       Cornerstone Search Group, LLC
# 3                                 Booz Allen Hamilton
# 4                                 Booz Allen Hamilton
# 5                                 Booz Allen Hamilton
# 6                                           Vox Media
# 7                                 Booz Allen Hamilton
# 8                                 Booz Allen Hamilton
# 9                                  Jobspring Partners
# 10                                               SAIC
# 11                                               CACI
# 12                    General Technical Services, LLC
# 13                                               CCRi
# 14                    Whiteboard Federal Technologies
# 15           Veteran Staffing Network of Easter Seals
# 16                      Systems & Technology Research
# 17                                     WhiteHawk Inc.
# 18                             Encore Search Partners
# 19                                     WhiteHawk Inc.
# 20                Integrity Applications Incorporated
# 21                                            Bechtel
# 22                                Liberty Information
# 23               Commonwealth Computer Research, Inc.
# 24                                 Jobspring Partners
# 25                                Berico Technologies
# 26                Integrity Applications Incorporated
# 27                                Booz Allen Hamilton
# 28                                Cisco Systems, Inc.
# 29                     Synchronoss Technologies, Inc.
# 30          Centers for Disease Control and Preven...
# 31                                           Celerity
# 32                               Department of Health
# 33                                Sphere of Influence
# 34                                 Jobspring Partners
# 35                                        Capital One
# 36                                             NVIDIA
# 37                  Personal Genome Diagnostics, Inc.
# 38                                        AstraZeneca
# 39                                Sphere of Influence
# 40                                     Selby Jennings
# 41                                 Fractal Industries
# 42                                     MedImmune, LLC
# 43                                           Zoomdata
# 44                          Amazon Web Services, Inc.
# 45                               Amazon Corporate LLC
#
#                                      Location    Salary           Title  \
# 0                               United States  110000.0  Data_Scientist
# 1                          Havre de Grace, MD  110000.0  Data_Scientist
# 2                            Philadelphia, PA  110000.0  Data_Scientist
# 3                              Washington, DC  110000.0  Data_Scientist
# 4                              Washington, DC  110000.0  Data_Scientist
# 5                              Alexandria, VA  110000.0  Data_Scientist
# 6                              Washington, DC  110000.0  Data_Scientist
# 7                         Chantilly, VA 20151  110000.0  Data_Scientist
# 8                                  McLean, VA  110000.0  Data_Scientist
# 9    Washington, DC 20005 (Logan Circle area)  110000.0  Data_Scientist
# 10                                 McLean, VA  110000.0  Data_Scientist
# 11           Washington, DC 20001 (Shaw area)  110000.0  Data_Scientist
# 12                                Adelphi, MD  110000.0  Data_Scientist
# 13                        Charlottesville, VA  110000.0  Data_Scientist
# 14                                Herndon, VA  110000.0  Data_Scientist
# 15                                 McLean, VA  110000.0  Data_Scientist
# 16        Arlington, VA 22203 (Bluemont area)  110000.0  Data_Scientist
# 17                              Baltimore, MD  110000.0  Data_Scientist
# 18                                 Reston, VA  110000.0  Data_Scientist
# 19                              Baltimore, MD  110000.0  Data_Scientist
# 20                          Silver Spring, MD  110000.0  Data_Scientist
# 21                                 Reston, VA  110000.0  Data_Scientist
# 22                         Havre de Grace, MD  110000.0  Data_Scientist
# 23  Charlottesville, VA 22901 (29 North area)  110000.0  Data_Scientist
# 24                                 McLean, VA  110000.0  Data_Scientist
# 25                           Gaithersburg, MD  110000.0  Data_Scientist
# 26                            Springfield, VA  110000.0  Data_Scientist
# 27                             Alexandria, VA  110000.0  Data_Scientist
# 28                               Columbia, MD  110000.0  Data_Scientist
# 29                                 Reston, VA  110000.0  Data_Scientist
# 30                             Washington, DC  110000.0  Data_Scientist
# 31                           McLean, VA 22102  110000.0  Data_Scientist
# 32                             Washington, DC  110000.0  Data_Scientist
# 33                                 McLean, VA  110000.0  Data_Scientist
# 34                                 Reston, VA  110000.0  Data_Scientist
# 35                                 McLean, VA  110000.0  Data_Scientist
# 36                  Charlottesville, VA 22902  110000.0  Data_Scientist
# 37         Baltimore, MD 21224 (Bayview area)  110000.0  Data_Scientist
# 38                           Gaithersburg, MD  110000.0  Data_Scientist
# 39                           McLean, VA 22102  110000.0  Data_Scientist
# 40                             Alexandria, VA  110000.0  Data_Scientist
# 41                                 Reston, VA  110000.0  Data_Scientist
# 42                           Gaithersburg, MD  110000.0  Data_Scientist
# 43                                 Reston, VA  110000.0  Data_Scientist
# 44                              United States  110000.0  Data_Scientist
# 45                              United States  110000.0  Data_Scientist
#
#      Experience
# 0   Entry_level
# 1   Entry_level
# 2   Entry_level
# 3   Entry_level
# 4   Entry_level
# 5   Entry_level
# 6   Entry_level
# 7   Entry_level
# 8   Entry_level
# 9   Entry_level
# 10  Entry_level
# 11  Entry_level
# 12  Entry_level
# 13  Entry_level
# 14  Entry_level
# 15  Entry_level
# 16  Entry_level
# 17  Entry_level
# 18  Entry_level
# 19  Entry_level
# 20  Entry_level
# 21  Entry_level
# 22  Entry_level
# 23  Entry_level
# 24  Entry_level
# 25  Entry_level
# 26  Entry_level
# 27  Entry_level
# 28  Entry_level
# 29  Entry_level
# 30  Entry_level
# 31  Entry_level
# 32  Entry_level
# 33  Entry_level
# 34  Entry_level
# 35  Entry_level
# 36  Entry_level
# 37  Entry_level
# 38  Entry_level
# 39  Entry_level
# 40  Entry_level
# 41  Entry_level
# 42  Entry_level
# 43  Entry_level
# 44  Entry_level
# 45  Entry_level

# %% [markdown]
# ## Data_scientist_DC_110_mid

# %%
driver = webdriver.Chrome()
url = "https://www.indeed.com/jobs?q=%22Data+Scientist%22+$110,000&l=%22Washington,+DC%22&radius=100&explvl=mid_level&limit=100"
driver.get(url)
# wait one second
sleep(1)
#grab the page source
html = driver.page_source
# BeautifulSoup it!
html = BeautifulSoup(html)
driver.close()

# I'm going to create my empty df first
import pandas as pd
dcarea_job1 = pd.DataFrame(columns=["Company_name"])
dcarea_job2 = pd.DataFrame(columns=["Location","Salary", "Title","Experience"])
# loop through each entry
for company in html.find_all('span', {'class':'company'}):
    name_comp = company.text
    dcarea_job1.loc[len(dcarea_job1)]=[name_comp]
    
for location in html.find_all('span', {'class':'location'}):
    loc_comp = location.text
    salary = 110000
    experience = "Mid_level"
    # try to find the number of bookings
    title = "Data_Scientist"
    dcarea_job2.loc[len(dcarea_job2)]=[loc_comp,salary,title,experience]

dcarea_job1['Company_name'] = dcarea_job1['Company_name'].str.replace('\n', '')
dcarea_job2['Location'] = dcarea_job2['Location'].str.replace('\n', '')

result_DC_110_mid = pd.concat([dcarea_job1, dcarea_job2], axis=1)

result_DC_110_mid
# Out:
#                                          Company_name  \
# 0                               The Verity Group, LLC
# 1              All Things Considered Staffing (ATC-S)
# 2                               Gunther Douglas, Inc.
# 3                                  Excella Consulting
# 4                                 Booz Allen Hamilton
# 5                                             Verizon
# 6                                          Barbaricum
# 7                                       Deutsche Bank
# 8                                    Oscar Technology
# 9                                             Novetta
# 10                                       ASRC Federal
# 11                                            Vencore
# 12          The Johns Hopkins Applied Physics Labo...
# 13                                            Novetta
# 14                                               CAVA
# 15              American Society of Clinical Oncology
# 16                                Booz Allen Hamilton
# 17                                        TransVoyant
# 18                                       ASRC Federal
# 19                  Altamira Technologies Corporation
# 20                                           Teradata
# 21                     The Upside Travel Company, LLC
# 22            Creative Associates International, Inc.
# 23                                  Aquila Technology
# 24                                        TransVoyant
# 25                                         IHS Markit
# 26                                  Mitre Corporation
# 27                                           In-Q-Tel
# 28                  Altamira Technologies Corporation
# 29                                               KPMG
# 30                                               KPMG
# 31                                 Jobspring Partners
# 32                            Smith Hanley Associates
# 33                                        Capital One
# 34                                    Solebrity, Inc.
# 35                  Altamira Technologies Corporation
# 36                     S&P GLOBAL MARKET INTELLIGENCE
# 37                                               KPMG
# 38                                  Mitre Corporation
# 39                     Elite Technical Services, Inc.
# 40                       Strategic Staffing Solutions
# 41                               Engility Corporation
# 42                                    PureIntegration
# 43                                        Capital One
# 44                                        Capital One
# 45                                        Capital One
# 46                                        Capital One
# 47                              The Verity Group, LLC
# 48                                               CAVA
# 49                           The Wallach Search Group
# 50                                   All-In Analytics
# 51                                        Capital One
# 52                                           Zoomdata
# 53                                  Mitre Corporation
# 54                                            Socrata
# 55                                        Capital One
# 56                                           Zoomdata
# 57                                           Zoomdata
# 58                     Atrilogy Solutions Group, Inc.
# 59                     The Upside Travel Company, LLC
#
#                                          Location    Salary           Title  \
# 0                                  Alexandria, VA  110000.0  Data_Scientist
# 1                                  Washington, DC  110000.0  Data_Scientist
# 2                            Washington, DC 20036  110000.0  Data_Scientist
# 3        Washington, DC 20006 (Foggy Bottom area)  110000.0  Data_Scientist
# 4                                  Washington, DC  110000.0  Data_Scientist
# 5                         Silver Spring, MD 20904  110000.0  Data_Scientist
# 6                                  Washington, DC  110000.0  Data_Scientist
# 7                                  Washington, DC  110000.0  Data_Scientist
# 8                                   Baltimore, MD  110000.0  Data_Scientist
# 9                                Crystal City, VA  110000.0  Data_Scientist
# 10                                 Alexandria, VA  110000.0  Data_Scientist
# 11                                     McLean, VA  110000.0  Data_Scientist
# 12                                     Laurel, MD  110000.0  Data_Scientist
# 13                                Springfield, VA  110000.0  Data_Scientist
# 14  Washington, DC 20009 (U Street Corridor area)  110000.0  Data_Scientist
# 15                                 Alexandria, VA  110000.0  Data_Scientist
# 16                                 Alexandria, VA  110000.0  Data_Scientist
# 17                           Alexandria, VA 22303  110000.0  Data_Scientist
# 18                                 Alexandria, VA  110000.0  Data_Scientist
# 19                                Springfield, VA  110000.0  Data_Scientist
# 20                                 Washington, DC  110000.0  Data_Scientist
# 21                                 Washington, DC  110000.0  Data_Scientist
# 22      Washington, DC 20015 (Barnaby Woods area)  110000.0  Data_Scientist
# 23                                Springfield, VA  110000.0  Data_Scientist
# 24                           Alexandria, VA 22303  110000.0  Data_Scientist
# 25                                 Washington, DC  110000.0  Data_Scientist
# 26         Washington, DC 20024 (South West area)  110000.0  Data_Scientist
# 27        Arlington, VA 22201 (Lyon Village area)  110000.0  Data_Scientist
# 28                                Springfield, VA  110000.0  Data_Scientist
# 29                                     McLean, VA  110000.0  Data_Scientist
# 30           Washington, DC 20036 (Downtown area)  110000.0  Data_Scientist
# 31                                     Reston, VA  110000.0  Data_Scientist
# 32                                 Washington, DC  110000.0  Data_Scientist
# 33                                     McLean, VA  110000.0  Data_Scientist
# 34                              Ashburn, VA 20147  110000.0  Data_Scientist
# 35                                  Chantilly, VA  110000.0  Data_Scientist
# 36    Charlottesville, VA 22909 (North East area)  110000.0  Data_Scientist
# 37           Washington, DC 20036 (Downtown area)  110000.0  Data_Scientist
# 38                                     McLean, VA  110000.0  Data_Scientist
# 39                                 Washington, DC  110000.0  Data_Scientist
# 40                                     McLean, VA  110000.0  Data_Scientist
# 41                            Chantilly, VA 20151  110000.0  Data_Scientist
# 42                                     Dulles, VA  110000.0  Data_Scientist
# 43                                     McLean, VA  110000.0  Data_Scientist
# 44                                     Vienna, VA  110000.0  Data_Scientist
# 45                                     McLean, VA  110000.0  Data_Scientist
# 46                                     McLean, VA  110000.0  Data_Scientist
# 47                                 Alexandria, VA  110000.0  Data_Scientist
# 48  Washington, DC 20009 (U Street Corridor area)  110000.0  Data_Scientist
# 49                                 Washington, DC  110000.0  Data_Scientist
# 50                                 Washington, DC  110000.0  Data_Scientist
# 51                                     Vienna, VA  110000.0  Data_Scientist
# 52                                     Reston, VA  110000.0  Data_Scientist
# 53                   Annapolis Junction, MD 20701  110000.0  Data_Scientist
# 54                                 Washington, DC  110000.0  Data_Scientist
# 55                                     McLean, VA  110000.0  Data_Scientist
# 56                                     Reston, VA  110000.0  Data_Scientist
# 57                                     Reston, VA  110000.0  Data_Scientist
# 58                           Washington, DC 20001  110000.0  Data_Scientist
# 59                                 Washington, DC  110000.0  Data_Scientist
#
#    Experience
# 0   Mid_level
# 1   Mid_level
# 2   Mid_level
# 3   Mid_level
# 4   Mid_level
# 5   Mid_level
# 6   Mid_level
# 7   Mid_level
# 8   Mid_level
# 9   Mid_level
# 10  Mid_level
# 11  Mid_level
# 12  Mid_level
# 13  Mid_level
# 14  Mid_level
# 15  Mid_level
# 16  Mid_level
# 17  Mid_level
# 18  Mid_level
# 19  Mid_level
# 20  Mid_level
# 21  Mid_level
# 22  Mid_level
# 23  Mid_level
# 24  Mid_level
# 25  Mid_level
# 26  Mid_level
# 27  Mid_level
# 28  Mid_level
# 29  Mid_level
# 30  Mid_level
# 31  Mid_level
# 32  Mid_level
# 33  Mid_level
# 34  Mid_level
# 35  Mid_level
# 36  Mid_level
# 37  Mid_level
# 38  Mid_level
# 39  Mid_level
# 40  Mid_level
# 41  Mid_level
# 42  Mid_level
# 43  Mid_level
# 44  Mid_level
# 45  Mid_level
# 46  Mid_level
# 47  Mid_level
# 48  Mid_level
# 49  Mid_level
# 50  Mid_level
# 51  Mid_level
# 52  Mid_level
# 53  Mid_level
# 54  Mid_level
# 55  Mid_level
# 56  Mid_level
# 57  Mid_level
# 58  Mid_level
# 59  Mid_level

# %% [markdown]
# ## Data_scientist_DC_110_senior

# %%
driver = webdriver.Chrome()
url = "https://www.indeed.com/jobs?q=%22Data+Scientist%22+$110,000&l=%22Washington,+DC%22&radius=100&explvl=senior_level&limit=100"
driver.get(url)
# wait one second
sleep(1)
#grab the page source
html = driver.page_source
# BeautifulSoup it!
html = BeautifulSoup(html)
driver.close()

# I'm going to create my empty df first
import pandas as pd
dcarea_job1 = pd.DataFrame(columns=["Company_name"])
dcarea_job2 = pd.DataFrame(columns=["Location","Salary", "Title","Experience"])
# loop through each entry
for company in html.find_all('span', {'class':'company'}):
    name_comp = company.text
    dcarea_job1.loc[len(dcarea_job1)]=[name_comp]
    
for location in html.find_all('span', {'class':'location'}):
    loc_comp = location.text
    salary = 110000
    experience = "Senior_level"
    # try to find the number of bookings
    title = "Data_Scientist"
    dcarea_job2.loc[len(dcarea_job2)]=[loc_comp,salary,title,experience]

dcarea_job1['Company_name'] = dcarea_job1['Company_name'].str.replace('\n', '')
dcarea_job2['Location'] = dcarea_job2['Location'].str.replace('\n', '')

result_DC_110_senior = pd.concat([dcarea_job1, dcarea_job2], axis=1)

result_DC_110_senior
# Out:
#                                  Company_name  \
# 0                                QuintilesIMS
# 1                                  System One
# 2                                       IMTAS
# 3                                        ITDC
# 4                                     Vencore
# 5                         Booz Allen Hamilton
# 6              Applied Communication Sciences
# 7                         Booz Allen Hamilton
# 8                         Booz Allen Hamilton
# 9                   The Aerospace Corporation
# 10                          SnagAJob.com, Inc
# 11                        Booz Allen Hamilton
# 12                                     Lotame
# 13                                    Vencore
# 14                          Mitre Corporation
# 15                        Booz Allen Hamilton
# 16                    Arch Capital Group Ltd.
# 17                         Praxis Engineering
# 18                   OnPoint Consulting, Inc.
# 19                                        EXL
# 20                                Capital One
# 21                          Mitre Corporation
# 22          Altamira Technologies Corporation
# 23                                        SC3
# 24                         Praxis Engineering
# 25                                       CCRi
# 26       Commonwealth Computer Research, Inc.
# 27                          EOIR Technologies
# 28                                   Zoomdata
# 29                                    TD Bank
#
#                                    Location    Salary           Title  \
# 0                          Collegeville, PA  110000.0  Data_Scientist
# 1                                Reston, VA  110000.0  Data_Scientist
# 2          Washington, DC 20001 (Shaw area)  110000.0  Data_Scientist
# 3                            Washington, DC  110000.0  Data_Scientist
# 4                                McLean, VA  110000.0  Data_Scientist
# 5                            Washington, DC  110000.0  Data_Scientist
# 6                          College Park, MD  110000.0  Data_Scientist
# 7                            Alexandria, VA  110000.0  Data_Scientist
# 8                            Alexandria, VA  110000.0  Data_Scientist
# 9                          Crystal City, VA  110000.0  Data_Scientist
# 10  Arlington, VA 22201 (Lyon Village area)  110000.0  Data_Scientist
# 11                      Chantilly, VA 20151  110000.0  Data_Scientist
# 12                       Columbia, MD 21045  110000.0  Data_Scientist
# 13                         College Park, MD  110000.0  Data_Scientist
# 14                             Bethesda, MD  110000.0  Data_Scientist
# 15                           Alexandria, VA  110000.0  Data_Scientist
# 16                           Washington, DC  110000.0  Data_Scientist
# 17                               Reston, VA  110000.0  Data_Scientist
# 18                            Arlington, VA  110000.0  Data_Scientist
# 19                           Wilmington, DE  110000.0  Data_Scientist
# 20                           Wilmington, DE  110000.0  Data_Scientist
# 21             Annapolis Junction, MD 20701  110000.0  Data_Scientist
# 22                            Chantilly, VA  110000.0  Data_Scientist
# 23                              Fairfax, VA  110000.0  Data_Scientist
# 24                               Reston, VA  110000.0  Data_Scientist
# 25                            Chantilly, VA  110000.0  Data_Scientist
# 26                            Chantilly, VA  110000.0  Data_Scientist
# 27                    Springfield, VA 22150  110000.0  Data_Scientist
# 28                               Reston, VA  110000.0  Data_Scientist
# 29                         Mount Laurel, NJ  110000.0  Data_Scientist
#
#       Experience
# 0   Senior_level
# 1   Senior_level
# 2   Senior_level
# 3   Senior_level
# 4   Senior_level
# 5   Senior_level
# 6   Senior_level
# 7   Senior_level
# 8   Senior_level
# 9   Senior_level
# 10  Senior_level
# 11  Senior_level
# 12  Senior_level
# 13  Senior_level
# 14  Senior_level
# 15  Senior_level
# 16  Senior_level
# 17  Senior_level
# 18  Senior_level
# 19  Senior_level
# 20  Senior_level
# 21  Senior_level
# 22  Senior_level
# 23  Senior_level
# 24  Senior_level
# 25  Senior_level
# 26  Senior_level
# 27  Senior_level
# 28  Senior_level
# 29  Senior_level

# %% [markdown]
# ## Data_scientist_DC_125_entry

# %%
driver = webdriver.Chrome()
url = "https://www.indeed.com/jobs?q=%22Data+Scientist%22+$125,000&l=%22Washington,+DC%22&radius=100&explvl=entry_level&limit=100"
driver.get(url)
# wait one second
sleep(1)
#grab the page source
html = driver.page_source
# BeautifulSoup it!
html = BeautifulSoup(html)
driver.close()

# I'm going to create my empty df first
import pandas as pd
dcarea_job1 = pd.DataFrame(columns=["Company_name"])
dcarea_job2 = pd.DataFrame(columns=["Location","Salary", "Title","Experience"])
# loop through each entry
for company in html.find_all('span', {'class':'company'}):
    name_comp = company.text
    dcarea_job1.loc[len(dcarea_job1)]=[name_comp]
    
for location in html.find_all('span', {'class':'location'}):
    loc_comp = location.text
    salary = 125000
    experience = "Entry_level"
    # try to find the number of bookings
    title = "Data_Scientist"
    dcarea_job2.loc[len(dcarea_job2)]=[loc_comp,salary,title,experience]

dcarea_job1['Company_name'] = dcarea_job1['Company_name'].str.replace('\n', '')
dcarea_job2['Location'] = dcarea_job2['Location'].str.replace('\n', '')

result_DC_125_entry = pd.concat([dcarea_job1, dcarea_job2], axis=1)

result_DC_125_entry
# Out:
#                                    Company_name  \
# 0                           Booz Allen Hamilton
# 1                           Booz Allen Hamilton
# 2                            Jobspring Partners
# 3               Whiteboard Federal Technologies
# 4      Veteran Staffing Network of Easter Seals
# 5                 Systems & Technology Research
# 6                                       Bechtel
# 7                            Jobspring Partners
# 8                                Selby Jennings
#
#                                    Location    Salary           Title  \
# 0                            Washington, DC  125000.0  Data_Scientist
# 1                                McLean, VA  125000.0  Data_Scientist
# 2  Washington, DC 20005 (Logan Circle area)  125000.0  Data_Scientist
# 3                               Herndon, VA  125000.0  Data_Scientist
# 4                                McLean, VA  125000.0  Data_Scientist
# 5       Arlington, VA 22203 (Bluemont area)  125000.0  Data_Scientist
# 6                                Reston, VA  125000.0  Data_Scientist
# 7                                McLean, VA  125000.0  Data_Scientist
# 8                            Alexandria, VA  125000.0  Data_Scientist
#
#     Experience
# 0  Entry_level
# 1  Entry_level
# 2  Entry_level
# 3  Entry_level
# 4  Entry_level
# 5  Entry_level
# 6  Entry_level
# 7  Entry_level
# 8  Entry_level

# %% [markdown]
# ## Data_scientist_DC_125_mid

# %%
driver = webdriver.Chrome()
url = "https://www.indeed.com/jobs?q=%22Data+Scientist%22+$125,000&l=%22Washington,+DC%22&radius=100&explvl=mid_level&limit=100"
driver.get(url)
# wait one second
sleep(1)
#grab the page source
html = driver.page_source
# BeautifulSoup it!
html = BeautifulSoup(html)
driver.close()

# I'm going to create my empty df first
import pandas as pd
dcarea_job1 = pd.DataFrame(columns=["Company_name"])
dcarea_job2 = pd.DataFrame(columns=["Location","Salary", "Title","Experience"])
# loop through each entry
for company in html.find_all('span', {'class':'company'}):
    name_comp = company.text
    dcarea_job1.loc[len(dcarea_job1)]=[name_comp]
    
for location in html.find_all('span', {'class':'location'}):
    loc_comp = location.text
    salary = 125000
    experience = "Mid_level"
    # try to find the number of bookings
    title = "Data_Scientist"
    dcarea_job2.loc[len(dcarea_job2)]=[loc_comp,salary,title,experience]

dcarea_job1['Company_name'] = dcarea_job1['Company_name'].str.replace('\n', '')
dcarea_job2['Location'] = dcarea_job2['Location'].str.replace('\n', '')

result_DC_125_mid = pd.concat([dcarea_job1, dcarea_job2], axis=1)

result_DC_125_mid
# Out:
#                                   Company_name  \
# 0                        The Verity Group, LLC
# 1               The Upside Travel Company, LLC
# 2                        Gunther Douglas, Inc.
# 3                                   Barbaricum
# 4                             Oscar Technology
# 5                          Booz Allen Hamilton
# 6                                  TransVoyant
# 7                                 ASRC Federal
# 8               The Upside Travel Company, LLC
# 9                                   IHS Markit
# 10                           Mitre Corporation
# 11                          Jobspring Partners
# 12                     Smith Hanley Associates
# 13                                 Capital One
# 14                             Solebrity, Inc.
# 15              S&P GLOBAL MARKET INTELLIGENCE
# 16              Elite Technical Services, Inc.
# 17                                 Capital One
# 18                                 Capital One
# 19                                 Capital One
# 20                                 Capital One
# 21                       The Verity Group, LLC
# 22                    The Wallach Search Group
# 23                                 Capital One
# 24      All Things Considered Staffing (ATC-S)
#
#                                        Location    Salary           Title  \
# 0                                Alexandria, VA  125000.0  Data_Scientist
# 1                                Washington, DC  125000.0  Data_Scientist
# 2                          Washington, DC 20036  125000.0  Data_Scientist
# 3                                Washington, DC  125000.0  Data_Scientist
# 4                                 Baltimore, MD  125000.0  Data_Scientist
# 5                                    Reston, VA  125000.0  Data_Scientist
# 6                          Alexandria, VA 22303  125000.0  Data_Scientist
# 7                                Alexandria, VA  125000.0  Data_Scientist
# 8                                Washington, DC  125000.0  Data_Scientist
# 9                                Washington, DC  125000.0  Data_Scientist
# 10       Washington, DC 20024 (South West area)  125000.0  Data_Scientist
# 11                                   Reston, VA  125000.0  Data_Scientist
# 12                               Washington, DC  125000.0  Data_Scientist
# 13                                   McLean, VA  125000.0  Data_Scientist
# 14                            Ashburn, VA 20147  125000.0  Data_Scientist
# 15  Charlottesville, VA 22909 (North East area)  125000.0  Data_Scientist
# 16                               Washington, DC  125000.0  Data_Scientist
# 17                                   McLean, VA  125000.0  Data_Scientist
# 18                                   Vienna, VA  125000.0  Data_Scientist
# 19                                   McLean, VA  125000.0  Data_Scientist
# 20                                   McLean, VA  125000.0  Data_Scientist
# 21                               Alexandria, VA  125000.0  Data_Scientist
# 22                               Washington, DC  125000.0  Data_Scientist
# 23                                   McLean, VA  125000.0  Data_Scientist
# 24                               Washington, DC  125000.0  Data_Scientist
#
#    Experience
# 0   Mid_level
# 1   Mid_level
# 2   Mid_level
# 3   Mid_level
# 4   Mid_level
# 5   Mid_level
# 6   Mid_level
# 7   Mid_level
# 8   Mid_level
# 9   Mid_level
# 10  Mid_level
# 11  Mid_level
# 12  Mid_level
# 13  Mid_level
# 14  Mid_level
# 15  Mid_level
# 16  Mid_level
# 17  Mid_level
# 18  Mid_level
# 19  Mid_level
# 20  Mid_level
# 21  Mid_level
# 22  Mid_level
# 23  Mid_level
# 24  Mid_level

# %% [markdown]
# ## Data_scientist_DC_125_senior

# %%
driver = webdriver.Chrome()
url = "https://www.indeed.com/jobs?q=%22Data+Scientist%22+$125,000%2B&l=%22Washington,+DC%22&radius=100&explvl=senior_level&limit=50"
driver.get(url)
# wait one second
sleep(1)
#grab the page source
html = driver.page_source
# BeautifulSoup it!
html = BeautifulSoup(html)
driver.close()

# I'm going to create my empty df first
import pandas as pd
dcarea_job1 = pd.DataFrame(columns=["Company_name"])
dcarea_job2 = pd.DataFrame(columns=["Location","Salary", "Title","Experience"])
# loop through each entry
for company in html.find_all('span', {'class':'company'}):
    name_comp = company.text
    dcarea_job1.loc[len(dcarea_job1)]=[name_comp]
    
for location in html.find_all('span', {'class':'location'}):
    loc_comp = location.text
    salary = 125000
    experience = "Senior_level"
    # try to find the number of bookings
    title = "Data_Scientist"
    dcarea_job2.loc[len(dcarea_job2)]=[loc_comp,salary,title,experience]

dcarea_job1['Company_name'] = dcarea_job1['Company_name'].str.replace('\n', '')
dcarea_job2['Location'] = dcarea_job2['Location'].str.replace('\n', '')

result_DC_125_senior = pd.concat([dcarea_job1, dcarea_job2], axis=1)

result_DC_125_senior
# Out:
#                                 Company_name  \
# 0                               QuintilesIMS
# 1                                 System One
# 2                                       ITDC
# 3                        Booz Allen Hamilton
# 4                          SnagAJob.com, Inc
# 5                        Booz Allen Hamilton
# 6                                     Lotame
# 7                        Booz Allen Hamilton
# 8                          Mitre Corporation
# 9                    Arch Capital Group Ltd.
# 10                                       EXL
# 11                               Capital One
# 12                        Praxis Engineering
# 13                                      CCRi
# 14      Commonwealth Computer Research, Inc.
# 15                                  Zoomdata
# 16                                   TD Bank
#
#                                    Location    Salary           Title  \
# 0                          Collegeville, PA  125000.0  Data_Scientist
# 1                                Reston, VA  125000.0  Data_Scientist
# 2                            Washington, DC  125000.0  Data_Scientist
# 3                            Washington, DC  125000.0  Data_Scientist
# 4   Arlington, VA 22201 (Lyon Village area)  125000.0  Data_Scientist
# 5                       Chantilly, VA 20151  125000.0  Data_Scientist
# 6                        Columbia, MD 21045  125000.0  Data_Scientist
# 7                            Alexandria, VA  125000.0  Data_Scientist
# 8                              Bethesda, MD  125000.0  Data_Scientist
# 9                            Washington, DC  125000.0  Data_Scientist
# 10                           Wilmington, DE  125000.0  Data_Scientist
# 11                           Wilmington, DE  125000.0  Data_Scientist
# 12                               Reston, VA  125000.0  Data_Scientist
# 13                            Chantilly, VA  125000.0  Data_Scientist
# 14                            Chantilly, VA  125000.0  Data_Scientist
# 15                               Reston, VA  125000.0  Data_Scientist
# 16                         Mount Laurel, NJ  125000.0  Data_Scientist
#
#       Experience
# 0   Senior_level
# 1   Senior_level
# 2   Senior_level
# 3   Senior_level
# 4   Senior_level
# 5   Senior_level
# 6   Senior_level
# 7   Senior_level
# 8   Senior_level
# 9   Senior_level
# 10  Senior_level
# 11  Senior_level
# 12  Senior_level
# 13  Senior_level
# 14  Senior_level
# 15  Senior_level
# 16  Senior_level

# %% [markdown]
# ## New york city

# %%
## Data_scientist_NY_85_entry

driver = webdriver.Chrome()
url = "https://www.indeed.com/jobs?q=%22Data+Scientist%22+$85,000%2B&l=New+York,+NY&radius=50&explvl=entry_level&limit=100"
driver.get(url)
# wait one second
sleep(1)
#grab the page source
html = driver.page_source
# BeautifulSoup it!
html = BeautifulSoup(html)
driver.close()

# I'm going to create my empty df first
import pandas as pd
dcarea_job1 = pd.DataFrame(columns=["Company_name"])
dcarea_job2 = pd.DataFrame(columns=["Location","Salary", "Title","Experience"])
# loop through each entry
for company in html.find_all('span', {'class':'company'}):
    name_comp = company.text
    dcarea_job1.loc[len(dcarea_job1)]=[name_comp]
    
for location in html.find_all('span', {'class':'location'}):
    loc_comp = location.text
    salary = 85000
    experience = "Entry_level"
    # try to find the number of bookings
    title = "Data_Scientist"
    dcarea_job2.loc[len(dcarea_job2)]=[loc_comp,salary,title,experience]

dcarea_job1['Company_name'] = dcarea_job1['Company_name'].str.replace('\n', '')
dcarea_job2['Location'] = dcarea_job2['Location'].str.replace('\n', '')

result_NY_85_entry = pd.concat([dcarea_job1, dcarea_job2], axis=1)

result_NY_85_entry

## Data_scientist_NY_85_mid

driver = webdriver.Chrome()
url = "https://www.indeed.com/jobs?q=%22Data+Scientist%22+$85,000%2B&l=New+York,+NY&radius=50&explvl=mid_level&limit=100"
driver.get(url)
# wait one second
sleep(1)
#grab the page source
html = driver.page_source
# BeautifulSoup it!
html = BeautifulSoup(html)
driver.close()

# I'm going to create my empty df first
import pandas as pd
dcarea_job1 = pd.DataFrame(columns=["Company_name"])
dcarea_job2 = pd.DataFrame(columns=["Location","Salary", "Title","Experience"])
# loop through each entry
for company in html.find_all('span', {'class':'company'}):
    name_comp = company.text
    dcarea_job1.loc[len(dcarea_job1)]=[name_comp]
    
for location in html.find_all('span', {'class':'location'}):
    loc_comp = location.text
    salary = 85000
    experience = "Mid_level"
    # try to find the number of bookings
    title = "Data_Scientist"
    dcarea_job2.loc[len(dcarea_job2)]=[loc_comp,salary,title,experience]

dcarea_job1['Company_name'] = dcarea_job1['Company_name'].str.replace('\n', '')
dcarea_job2['Location'] = dcarea_job2['Location'].str.replace('\n', '')

result_NY_85_mid = pd.concat([dcarea_job1, dcarea_job2], axis=1)

result_NY_85_mid

## Data_scientist_NY_85_senior

driver = webdriver.Chrome()
url = "https://www.indeed.com/jobs?q=%22Data+Scientist%22+$85,000%2B&l=New+York,+NY&radius=50&explvl=senior_level&limit=100"
driver.get(url)
# wait one second
sleep(1)
#grab the page source
html = driver.page_source
# BeautifulSoup it!
html = BeautifulSoup(html)
driver.close()

# I'm going to create my empty df first
import pandas as pd
dcarea_job1 = pd.DataFrame(columns=["Company_name"])
dcarea_job2 = pd.DataFrame(columns=["Location","Salary", "Title","Experience"])
# loop through each entry
for company in html.find_all('span', {'class':'company'}):
    name_comp = company.text
    dcarea_job1.loc[len(dcarea_job1)]=[name_comp]
    
for location in html.find_all('span', {'class':'location'}):
    loc_comp = location.text
    salary = 85000
    experience = "Senior_level"
    # try to find the number of bookings
    title = "Data_Scientist"
    dcarea_job2.loc[len(dcarea_job2)]=[loc_comp,salary,title,experience]

dcarea_job1['Company_name'] = dcarea_job1['Company_name'].str.replace('\n', '')
dcarea_job2['Location'] = dcarea_job2['Location'].str.replace('\n', '')

result_NY_85_senior = pd.concat([dcarea_job1, dcarea_job2], axis=1)

result_NY_85_senior
# Out:
#                                Company_name  \
# 0                                 Accenture
# 1                                   Harnham
# 2                                   TD Bank
# 3                MassMutual Financial Group
# 4                        MLB Advanced Media
# 5                                 Bloomberg
# 6                    Sapient Global Markets
# 7                                      TIAA
# 8                            Paperless Post
# 9                                   Averity
# 10                     Church Pension Group
# 11                                    Aetna
# 12                                  Spreemo
# 13                         Pivotal Software
# 14                              Absolutdata
# 15                          SRP Systems Inc
# 16                                    CAPCO
# 17                                  Spotify
# 18                                      AIG
# 19                                 SiriusXM
# 20                                      FIS
# 21                                   Enigma
# 22                                   Tumblr
# 23                                   Viacom
# 24                               S&P GLOBAL
# 25                        Rockstar New York
# 26                                  Harnham
# 27                              Helix Sleep
# 28                    Big Cloud Recruitment
# 29                                  Harnham
# 30                                LearnVest
# 31                          SRP Systems Inc
# 32                                Accenture
# 33                                      KCS
# 34                                      AIG
# 35                      Garrison Associates
# 36                                  Averity
# 37          Johnson & Johnson Services Inc.
# 38                        FGP International
# 39                                Accenture
# 40                                      SAP
# 41                The James Allen Companies
# 42                              MarketShare
# 43                                 Datameer
#
#                                         Location   Salary           Title  \
# 0                             New York, NY 10011  85000.0  Data_Scientist
# 1                             New York, NY 10150  85000.0  Data_Scientist
# 2                               Mount Laurel, NJ  85000.0  Data_Scientist
# 3                                   New York, NY  85000.0  Data_Scientist
# 4              New York, NY 10011 (Chelsea area)  85000.0  Data_Scientist
# 5                                   New York, NY  85000.0  Data_Scientist
# 6                                   New York, NY  85000.0  Data_Scientist
# 7      New York, NY 10002 (Lower East Side area)  85000.0  Data_Scientist
# 8                                   New York, NY  85000.0  Data_Scientist
# 9                                   New York, NY  85000.0  Data_Scientist
# 10                                  New York, NY  85000.0  Data_Scientist
# 11            New York, NY 10016 (Gramercy area)  85000.0  Data_Scientist
# 12                                  New York, NY  85000.0  Data_Scientist
# 13             New York, NY 10017 (Midtown area)  85000.0  Data_Scientist
# 14                                  New York, NY  85000.0  Data_Scientist
# 15                                 Princeton, NJ  85000.0  Data_Scientist
# 16  New York, NY 10271 (Financial District area)  85000.0  Data_Scientist
# 17             New York, NY 10011 (Chelsea area)  85000.0  Data_Scientist
# 18                                  New York, NY  85000.0  Data_Scientist
# 19                Township of Lawrence, NJ 08648  85000.0  Data_Scientist
# 20              New York, NY 10034 (Inwood area)  85000.0  Data_Scientist
# 21                                  New York, NY  85000.0  Data_Scientist
# 22                                  New York, NY  85000.0  Data_Scientist
# 23                                  New York, NY  85000.0  Data_Scientist
# 24     New York, NY 10002 (Lower East Side area)  85000.0  Data_Scientist
# 25                                  New York, NY  85000.0  Data_Scientist
# 26                                  New York, NY  85000.0  Data_Scientist
# 27                                  New York, NY  85000.0  Data_Scientist
# 28                                  New York, NY  85000.0  Data_Scientist
# 29                                  New York, NY  85000.0  Data_Scientist
# 30                                  New York, NY  85000.0  Data_Scientist
# 31                                 Princeton, NJ  85000.0  Data_Scientist
# 32             New York, NY 10011 (Chelsea area)  85000.0  Data_Scientist
# 33                                  New York, NY  85000.0  Data_Scientist
# 34                                  New York, NY  85000.0  Data_Scientist
# 35        New York, NY 10110 (East Village area)  85000.0  Data_Scientist
# 36                                     Union, NJ  85000.0  Data_Scientist
# 37                               Bridgewater, NJ  85000.0  Data_Scientist
# 38                                  New York, NY  85000.0  Data_Scientist
# 39             New York, NY 10011 (Chelsea area)  85000.0  Data_Scientist
# 40                                Parsippany, NJ  85000.0  Data_Scientist
# 41                               Jersey City, NJ  85000.0  Data_Scientist
# 42                                  New York, NY  85000.0  Data_Scientist
# 43                                  New York, NY  85000.0  Data_Scientist
#
#       Experience
# 0   Senior_level
# 1   Senior_level
# 2   Senior_level
# 3   Senior_level
# 4   Senior_level
# 5   Senior_level
# 6   Senior_level
# 7   Senior_level
# 8   Senior_level
# 9   Senior_level
# 10  Senior_level
# 11  Senior_level
# 12  Senior_level
# 13  Senior_level
# 14  Senior_level
# 15  Senior_level
# 16  Senior_level
# 17  Senior_level
# 18  Senior_level
# 19  Senior_level
# 20  Senior_level
# 21  Senior_level
# 22  Senior_level
# 23  Senior_level
# 24  Senior_level
# 25  Senior_level
# 26  Senior_level
# 27  Senior_level
# 28  Senior_level
# 29  Senior_level
# 30  Senior_level
# 31  Senior_level
# 32  Senior_level
# 33  Senior_level
# 34  Senior_level
# 35  Senior_level
# 36  Senior_level
# 37  Senior_level
# 38  Senior_level
# 39  Senior_level
# 40  Senior_level
# 41  Senior_level
# 42  Senior_level
# 43  Senior_level

# %%
##Data_scientist_NY_100_entry

driver = webdriver.Chrome()
url = "https://www.indeed.com/jobs?q=%22Data+Scientist%22+$100,000&l=New+York,+NY&radius=50&explvl=entry_level&limit=100"
driver.get(url)
# wait one second
sleep(1)
#grab the page source
html = driver.page_source
# BeautifulSoup it!
html = BeautifulSoup(html)
driver.close()

# I'm going to create my empty df first
import pandas as pd
dcarea_job1 = pd.DataFrame(columns=["Company_name"])
dcarea_job2 = pd.DataFrame(columns=["Location","Salary", "Title","Experience"])
# loop through each entry
for company in html.find_all('span', {'class':'company'}):
    name_comp = company.text
    dcarea_job1.loc[len(dcarea_job1)]=[name_comp]
    
for location in html.find_all('span', {'class':'location'}):
    loc_comp = location.text
    salary = 100000
    experience = "Entry_level"
    # try to find the number of bookings
    title = "Data_Scientist"
    dcarea_job2.loc[len(dcarea_job2)]=[loc_comp,salary,title,experience]

dcarea_job1['Company_name'] = dcarea_job1['Company_name'].str.replace('\n', '')
dcarea_job2['Location'] = dcarea_job2['Location'].str.replace('\n', '')

result_NY_100_entry = pd.concat([dcarea_job1, dcarea_job2], axis=1)

result_NY_100_entry

## Data_scientist_NY_100_mid

driver = webdriver.Chrome()
url = "https://www.indeed.com/jobs?q=%22Data+Scientist%22+$100,000&l=New+York,+NY&radius=50&explvl=mid_level&limit=100"
driver.get(url)
# wait one second
sleep(1)
#grab the page source
html = driver.page_source
# BeautifulSoup it!
html = BeautifulSoup(html)
driver.close()

# I'm going to create my empty df first
import pandas as pd
dcarea_job1 = pd.DataFrame(columns=["Company_name"])
dcarea_job2 = pd.DataFrame(columns=["Location","Salary", "Title","Experience"])
# loop through each entry
for company in html.find_all('span', {'class':'company'}):
    name_comp = company.text
    dcarea_job1.loc[len(dcarea_job1)]=[name_comp]
    
for location in html.find_all('span', {'class':'location'}):
    loc_comp = location.text
    salary = 100000
    experience = "Mid_level"
    # try to find the number of bookings
    title = "Data_Scientist"
    dcarea_job2.loc[len(dcarea_job2)]=[loc_comp,salary,title,experience]

dcarea_job1['Company_name'] = dcarea_job1['Company_name'].str.replace('\n', '')
dcarea_job2['Location'] = dcarea_job2['Location'].str.replace('\n', '')

result_NY_100_mid = pd.concat([dcarea_job1, dcarea_job2], axis=1)

result_NY_100_mid

## Data_scientist_NY_100_senior

driver = webdriver.Chrome()
url = "https://www.indeed.com/jobs?q=%22Data+Scientist%22+$100,000&l=New+York,+NY&radius=50&explvl=senior_level&limit=100"
driver.get(url)
# wait one second
sleep(1)
#grab the page source
html = driver.page_source
# BeautifulSoup it!
html = BeautifulSoup(html)
driver.close()

# I'm going to create my empty df first
import pandas as pd
dcarea_job1 = pd.DataFrame(columns=["Company_name"])
dcarea_job2 = pd.DataFrame(columns=["Location","Salary", "Title","Experience"])
# loop through each entry
for company in html.find_all('span', {'class':'company'}):
    name_comp = company.text
    dcarea_job1.loc[len(dcarea_job1)]=[name_comp]
    
for location in html.find_all('span', {'class':'location'}):
    loc_comp = location.text
    salary = 100000
    experience = "Senior_level"
    # try to find the number of bookings
    title = "Data_Scientist"
    dcarea_job2.loc[len(dcarea_job2)]=[loc_comp,salary,title,experience]

dcarea_job1['Company_name'] = dcarea_job1['Company_name'].str.replace('\n', '')
dcarea_job2['Location'] = dcarea_job2['Location'].str.replace('\n', '')

result_NY_100_senior = pd.concat([dcarea_job1, dcarea_job2], axis=1)

result_NY_100_senior
# Out:
#                                Company_name  \
# 0                                 Accenture
# 1                                   Harnham
# 2                                   TD Bank
# 3                MassMutual Financial Group
# 4                        MLB Advanced Media
# 5                    Sapient Global Markets
# 6                                 Bloomberg
# 7                                      TIAA
# 8                            Paperless Post
# 9                                   Averity
# 10                     Church Pension Group
# 11                                    Aetna
# 12                                  Spreemo
# 13                              Absolutdata
# 14                         Pivotal Software
# 15                                  Spotify
# 16                                    CAPCO
# 17                                      AIG
# 18                                   Enigma
# 19                                   Tumblr
# 20                               S&P GLOBAL
# 21                                   Viacom
# 22                                  Harnham
# 23                        Rockstar New York
# 24                                  Harnham
# 25                    Big Cloud Recruitment
# 26                                LearnVest
# 27                          SRP Systems Inc
# 28                                Accenture
# 29                                      KCS
# 30                                  Averity
# 31                      Garrison Associates
# 32                                      AIG
# 33          Johnson & Johnson Services Inc.
# 34                        FGP International
# 35                                      SAP
# 36                                Accenture
# 37                The James Allen Companies
# 38                              MarketShare
# 39                                 Datameer
#
#                                         Location    Salary           Title  \
# 0                             New York, NY 10011  100000.0  Data_Scientist
# 1                             New York, NY 10150  100000.0  Data_Scientist
# 2                               Mount Laurel, NJ  100000.0  Data_Scientist
# 3                                   New York, NY  100000.0  Data_Scientist
# 4              New York, NY 10011 (Chelsea area)  100000.0  Data_Scientist
# 5                                   New York, NY  100000.0  Data_Scientist
# 6                                   New York, NY  100000.0  Data_Scientist
# 7      New York, NY 10002 (Lower East Side area)  100000.0  Data_Scientist
# 8                                   New York, NY  100000.0  Data_Scientist
# 9                                   New York, NY  100000.0  Data_Scientist
# 10                                  New York, NY  100000.0  Data_Scientist
# 11            New York, NY 10016 (Gramercy area)  100000.0  Data_Scientist
# 12                                  New York, NY  100000.0  Data_Scientist
# 13                                  New York, NY  100000.0  Data_Scientist
# 14             New York, NY 10017 (Midtown area)  100000.0  Data_Scientist
# 15             New York, NY 10011 (Chelsea area)  100000.0  Data_Scientist
# 16  New York, NY 10271 (Financial District area)  100000.0  Data_Scientist
# 17                                  New York, NY  100000.0  Data_Scientist
# 18                                  New York, NY  100000.0  Data_Scientist
# 19                                  New York, NY  100000.0  Data_Scientist
# 20     New York, NY 10002 (Lower East Side area)  100000.0  Data_Scientist
# 21                                  New York, NY  100000.0  Data_Scientist
# 22                                  New York, NY  100000.0  Data_Scientist
# 23                                  New York, NY  100000.0  Data_Scientist
# 24                                  New York, NY  100000.0  Data_Scientist
# 25                                  New York, NY  100000.0  Data_Scientist
# 26                                  New York, NY  100000.0  Data_Scientist
# 27                                 Princeton, NJ  100000.0  Data_Scientist
# 28             New York, NY 10011 (Chelsea area)  100000.0  Data_Scientist
# 29                                  New York, NY  100000.0  Data_Scientist
# 30                                     Union, NJ  100000.0  Data_Scientist
# 31        New York, NY 10110 (East Village area)  100000.0  Data_Scientist
# 32                                  New York, NY  100000.0  Data_Scientist
# 33                               Bridgewater, NJ  100000.0  Data_Scientist
# 34                                  New York, NY  100000.0  Data_Scientist
# 35                                Parsippany, NJ  100000.0  Data_Scientist
# 36             New York, NY 10011 (Chelsea area)  100000.0  Data_Scientist
# 37                               Jersey City, NJ  100000.0  Data_Scientist
# 38                                  New York, NY  100000.0  Data_Scientist
# 39                                  New York, NY  100000.0  Data_Scientist
#
#       Experience
# 0   Senior_level
# 1   Senior_level
# 2   Senior_level
# 3   Senior_level
# 4   Senior_level
# 5   Senior_level
# 6   Senior_level
# 7   Senior_level
# 8   Senior_level
# 9   Senior_level
# 10  Senior_level
# 11  Senior_level
# 12  Senior_level
# 13  Senior_level
# 14  Senior_level
# 15  Senior_level
# 16  Senior_level
# 17  Senior_level
# 18  Senior_level
# 19  Senior_level
# 20  Senior_level
# 21  Senior_level
# 22  Senior_level
# 23  Senior_level
# 24  Senior_level
# 25  Senior_level
# 26  Senior_level
# 27  Senior_level
# 28  Senior_level
# 29  Senior_level
# 30  Senior_level
# 31  Senior_level
# 32  Senior_level
# 33  Senior_level
# 34  Senior_level
# 35  Senior_level
# 36  Senior_level
# 37  Senior_level
# 38  Senior_level
# 39  Senior_level

# %%
##Data_scientist_NY_115_entry

driver = webdriver.Chrome()
url = "https://www.indeed.com/jobs?q=%22Data+Scientist%22+$115,000&l=New+York,+NY&radius=50&explvl=entry_level&limit=100"
driver.get(url)
# wait one second
sleep(1)
#grab the page source
html = driver.page_source
# BeautifulSoup it!
html = BeautifulSoup(html)
driver.close()

# I'm going to create my empty df first
import pandas as pd
dcarea_job1 = pd.DataFrame(columns=["Company_name"])
dcarea_job2 = pd.DataFrame(columns=["Location","Salary", "Title","Experience"])
# loop through each entry
for company in html.find_all('span', {'class':'company'}):
    name_comp = company.text
    dcarea_job1.loc[len(dcarea_job1)]=[name_comp]
    
for location in html.find_all('span', {'class':'location'}):
    loc_comp = location.text
    salary = 115000
    experience = "Entry_level"
    # try to find the number of bookings
    title = "Data_Scientist"
    dcarea_job2.loc[len(dcarea_job2)]=[loc_comp,salary,title,experience]

dcarea_job1['Company_name'] = dcarea_job1['Company_name'].str.replace('\n', '')
dcarea_job2['Location'] = dcarea_job2['Location'].str.replace('\n', '')

result_NY_115_entry = pd.concat([dcarea_job1, dcarea_job2], axis=1)

result_NY_115_entry

##Data_scientist_NY_115_mid


driver = webdriver.Chrome()
url = "https://www.indeed.com/jobs?q=%22Data+Scientist%22+$115,000&l=New+York,+NY&radius=50&explvl=mid_level&limit=100"
driver.get(url)
# wait one second
sleep(1)
#grab the page source
html = driver.page_source
# BeautifulSoup it!
html = BeautifulSoup(html)
driver.close()

# I'm going to create my empty df first
import pandas as pd
dcarea_job1 = pd.DataFrame(columns=["Company_name"])
dcarea_job2 = pd.DataFrame(columns=["Location","Salary", "Title","Experience"])
# loop through each entry
for company in html.find_all('span', {'class':'company'}):
    name_comp = company.text
    dcarea_job1.loc[len(dcarea_job1)]=[name_comp]
    
for location in html.find_all('span', {'class':'location'}):
    loc_comp = location.text
    salary = 115000
    experience = "Mid_level"
    # try to find the number of bookings
    title = "Data_Scientist"
    dcarea_job2.loc[len(dcarea_job2)]=[loc_comp,salary,title,experience]

dcarea_job1['Company_name'] = dcarea_job1['Company_name'].str.replace('\n', '')
dcarea_job2['Location'] = dcarea_job2['Location'].str.replace('\n', '')

result_NY_115_mid = pd.concat([dcarea_job1, dcarea_job2], axis=1)

result_NY_115_mid

##Data_scientist_NY_115_senior

driver = webdriver.Chrome()
url = "https://www.indeed.com/jobs?q=%22Data+Scientist%22+$115,000&l=New+York,+NY&radius=50&explvl=senior_level&limit=100"
driver.get(url)
# wait one second
sleep(1)
#grab the page source
html = driver.page_source
# BeautifulSoup it!
html = BeautifulSoup(html)
driver.close()

# I'm going to create my empty df first
import pandas as pd
dcarea_job1 = pd.DataFrame(columns=["Company_name"])
dcarea_job2 = pd.DataFrame(columns=["Location","Salary", "Title","Experience"])
# loop through each entry
for company in html.find_all('span', {'class':'company'}):
    name_comp = company.text
    dcarea_job1.loc[len(dcarea_job1)]=[name_comp]
    
for location in html.find_all('span', {'class':'location'}):
    loc_comp = location.text
    salary = 115000
    experience = "Senior_level"
    # try to find the number of bookings
    title = "Data_Scientist"
    dcarea_job2.loc[len(dcarea_job2)]=[loc_comp,salary,title,experience]

dcarea_job1['Company_name'] = dcarea_job1['Company_name'].str.replace('\n', '')
dcarea_job2['Location'] = dcarea_job2['Location'].str.replace('\n', '')

result_NY_115_senior = pd.concat([dcarea_job1, dcarea_job2], axis=1)

result_NY_115_senior
# Out:
#                                Company_name  \
# 0                                 Accenture
# 1                                   Harnham
# 2                                   TD Bank
# 3                        MLB Advanced Media
# 4                                 Bloomberg
# 5                    Sapient Global Markets
# 6                            Paperless Post
# 7                                   Averity
# 8                                     Aetna
# 9                                   Spreemo
# 10                         Pivotal Software
# 11                              Absolutdata
# 12                                  Spotify
# 13                                      AIG
# 14                                   Tumblr
# 15                                   Viacom
# 16                               S&P GLOBAL
# 17                                    CAPCO
# 18                        Rockstar New York
# 19                                  Harnham
# 20                    Big Cloud Recruitment
# 21                                  Harnham
# 22                                Accenture
# 23                                      KCS
# 24                                      AIG
# 25                      Garrison Associates
# 26                                  Averity
# 27          Johnson & Johnson Services Inc.
# 28                        FGP International
# 29                                Accenture
# 30                The James Allen Companies
# 31                      Celgene Corporation
#
#                                         Location    Salary           Title  \
# 0                             New York, NY 10011  115000.0  Data_Scientist
# 1                             New York, NY 10150  115000.0  Data_Scientist
# 2                               Mount Laurel, NJ  115000.0  Data_Scientist
# 3              New York, NY 10011 (Chelsea area)  115000.0  Data_Scientist
# 4                                   New York, NY  115000.0  Data_Scientist
# 5                                   New York, NY  115000.0  Data_Scientist
# 6                                   New York, NY  115000.0  Data_Scientist
# 7                                   New York, NY  115000.0  Data_Scientist
# 8             New York, NY 10016 (Gramercy area)  115000.0  Data_Scientist
# 9                                   New York, NY  115000.0  Data_Scientist
# 10             New York, NY 10017 (Midtown area)  115000.0  Data_Scientist
# 11                                  New York, NY  115000.0  Data_Scientist
# 12             New York, NY 10011 (Chelsea area)  115000.0  Data_Scientist
# 13                                  New York, NY  115000.0  Data_Scientist
# 14                                  New York, NY  115000.0  Data_Scientist
# 15                                  New York, NY  115000.0  Data_Scientist
# 16     New York, NY 10002 (Lower East Side area)  115000.0  Data_Scientist
# 17  New York, NY 10271 (Financial District area)  115000.0  Data_Scientist
# 18                                  New York, NY  115000.0  Data_Scientist
# 19                                  New York, NY  115000.0  Data_Scientist
# 20                                  New York, NY  115000.0  Data_Scientist
# 21                                  New York, NY  115000.0  Data_Scientist
# 22             New York, NY 10011 (Chelsea area)  115000.0  Data_Scientist
# 23                                  New York, NY  115000.0  Data_Scientist
# 24                                  New York, NY  115000.0  Data_Scientist
# 25        New York, NY 10110 (East Village area)  115000.0  Data_Scientist
# 26                                     Union, NJ  115000.0  Data_Scientist
# 27                               Bridgewater, NJ  115000.0  Data_Scientist
# 28                                  New York, NY  115000.0  Data_Scientist
# 29             New York, NY 10011 (Chelsea area)  115000.0  Data_Scientist
# 30                               Jersey City, NJ  115000.0  Data_Scientist
# 31                              Summit, NJ 07901  115000.0  Data_Scientist
#
#       Experience
# 0   Senior_level
# 1   Senior_level
# 2   Senior_level
# 3   Senior_level
# 4   Senior_level
# 5   Senior_level
# 6   Senior_level
# 7   Senior_level
# 8   Senior_level
# 9   Senior_level
# 10  Senior_level
# 11  Senior_level
# 12  Senior_level
# 13  Senior_level
# 14  Senior_level
# 15  Senior_level
# 16  Senior_level
# 17  Senior_level
# 18  Senior_level
# 19  Senior_level
# 20  Senior_level
# 21  Senior_level
# 22  Senior_level
# 23  Senior_level
# 24  Senior_level
# 25  Senior_level
# 26  Senior_level
# 27  Senior_level
# 28  Senior_level
# 29  Senior_level
# 30  Senior_level
# 31  Senior_level

# %%
##Data_scientist_NY_125_entry

driver = webdriver.Chrome()
url = "https://www.indeed.com/jobs?q=%22Data+Scientist%22+$125,000&l=New+York,+NY&radius=50&explvl=entry_level&limit=100"
driver.get(url)
# wait one second
sleep(1)
#grab the page source
html = driver.page_source
# BeautifulSoup it!
html = BeautifulSoup(html)
driver.close()

# I'm going to create my empty df first
import pandas as pd
dcarea_job1 = pd.DataFrame(columns=["Company_name"])
dcarea_job2 = pd.DataFrame(columns=["Location","Salary", "Title","Experience"])
# loop through each entry
for company in html.find_all('span', {'class':'company'}):
    name_comp = company.text
    dcarea_job1.loc[len(dcarea_job1)]=[name_comp]
    
for location in html.find_all('span', {'class':'location'}):
    loc_comp = location.text
    salary = 125000
    experience = "Entry_level"
    # try to find the number of bookings
    title = "Data_Scientist"
    dcarea_job2.loc[len(dcarea_job2)]=[loc_comp,salary,title,experience]

dcarea_job1['Company_name'] = dcarea_job1['Company_name'].str.replace('\n', '')
dcarea_job2['Location'] = dcarea_job2['Location'].str.replace('\n', '')

result_NY_125_entry = pd.concat([dcarea_job1, dcarea_job2], axis=1)

result_NY_125_entry

##Data_scientist_NY_125_mid


driver = webdriver.Chrome()
url = "https://www.indeed.com/jobs?q=%22Data+Scientist%22+$125,000&l=New+York,+NY&radius=50&explvl=mid_level&limit=100"
driver.get(url)
# wait one second
sleep(1)
#grab the page source
html = driver.page_source
# BeautifulSoup it!
html = BeautifulSoup(html)
driver.close()

# I'm going to create my empty df first
import pandas as pd
dcarea_job1 = pd.DataFrame(columns=["Company_name"])
dcarea_job2 = pd.DataFrame(columns=["Location","Salary", "Title","Experience"])
# loop through each entry
for company in html.find_all('span', {'class':'company'}):
    name_comp = company.text
    dcarea_job1.loc[len(dcarea_job1)]=[name_comp]
    
for location in html.find_all('span', {'class':'location'}):
    loc_comp = location.text
    salary = 125000
    experience = "Mid_level"
    # try to find the number of bookings
    title = "Data_Scientist"
    dcarea_job2.loc[len(dcarea_job2)]=[loc_comp,salary,title,experience]

dcarea_job1['Company_name'] = dcarea_job1['Company_name'].str.replace('\n', '')
dcarea_job2['Location'] = dcarea_job2['Location'].str.replace('\n', '')

result_NY_125_mid = pd.concat([dcarea_job1, dcarea_job2], axis=1)

result_NY_125_mid

##Data_scientist_NY_125_senior

driver = webdriver.Chrome()
url = "https://www.indeed.com/jobs?q=%22Data+Scientist%22+$125,000&l=New+York,+NY&radius=50&explvl=senior_level&limit=100"
driver.get(url)
# wait one second
sleep(1)
#grab the page source
html = driver.page_source
# BeautifulSoup it!
html = BeautifulSoup(html)
driver.close()

# I'm going to create my empty df first
import pandas as pd
dcarea_job1 = pd.DataFrame(columns=["Company_name"])
dcarea_job2 = pd.DataFrame(columns=["Location","Salary", "Title","Experience"])
# loop through each entry
for company in html.find_all('span', {'class':'company'}):
    name_comp = company.text
    dcarea_job1.loc[len(dcarea_job1)]=[name_comp]
    
for location in html.find_all('span', {'class':'location'}):
    loc_comp = location.text
    salary = 125000
    experience = "Senior_level"
    # try to find the number of bookings
    title = "Data_Scientist"
    dcarea_job2.loc[len(dcarea_job2)]=[loc_comp,salary,title,experience]

dcarea_job1['Company_name'] = dcarea_job1['Company_name'].str.replace('\n', '')
dcarea_job2['Location'] = dcarea_job2['Location'].str.replace('\n', '')

result_NY_125_senior = pd.concat([dcarea_job1, dcarea_job2], axis=1)

result_NY_125_senior
# Out:
#                                Company_name  \
# 0                                 Accenture
# 1                                   Harnham
# 2                       Celgene Corporation
# 3                        MLB Advanced Media
# 4                    Sapient Global Markets
# 5                                 Bloomberg
# 6                            Paperless Post
# 7                                   Averity
# 8                                   Spreemo
# 9                               Absolutdata
# 10                         Pivotal Software
# 11                                  Spotify
# 12                                      AIG
# 13                                   Tumblr
# 14                               S&P GLOBAL
# 15                                   Viacom
# 16                                  Harnham
# 17                        Rockstar New York
# 18                                  Harnham
# 19                    Big Cloud Recruitment
# 20                                Accenture
# 21                                      KCS
# 22                                  Averity
# 23                      Garrison Associates
# 24                                      AIG
# 25          Johnson & Johnson Services Inc.
# 26                                Accenture
# 27                The James Allen Companies
# 28                                  TD Bank
#
#                                      Location    Salary           Title  \
# 0                          New York, NY 10011  125000.0  Data_Scientist
# 1                          New York, NY 10150  125000.0  Data_Scientist
# 2                            Summit, NJ 07901  125000.0  Data_Scientist
# 3           New York, NY 10011 (Chelsea area)  125000.0  Data_Scientist
# 4                                New York, NY  125000.0  Data_Scientist
# 5                                New York, NY  125000.0  Data_Scientist
# 6                                New York, NY  125000.0  Data_Scientist
# 7                                New York, NY  125000.0  Data_Scientist
# 8                                New York, NY  125000.0  Data_Scientist
# 9                                New York, NY  125000.0  Data_Scientist
# 10          New York, NY 10017 (Midtown area)  125000.0  Data_Scientist
# 11          New York, NY 10011 (Chelsea area)  125000.0  Data_Scientist
# 12                               New York, NY  125000.0  Data_Scientist
# 13                               New York, NY  125000.0  Data_Scientist
# 14  New York, NY 10002 (Lower East Side area)  125000.0  Data_Scientist
# 15                               New York, NY  125000.0  Data_Scientist
# 16                               New York, NY  125000.0  Data_Scientist
# 17                               New York, NY  125000.0  Data_Scientist
# 18                               New York, NY  125000.0  Data_Scientist
# 19                               New York, NY  125000.0  Data_Scientist
# 20          New York, NY 10011 (Chelsea area)  125000.0  Data_Scientist
# 21                               New York, NY  125000.0  Data_Scientist
# 22                                  Union, NJ  125000.0  Data_Scientist
# 23     New York, NY 10110 (East Village area)  125000.0  Data_Scientist
# 24                               New York, NY  125000.0  Data_Scientist
# 25                            Bridgewater, NJ  125000.0  Data_Scientist
# 26          New York, NY 10011 (Chelsea area)  125000.0  Data_Scientist
# 27                            Jersey City, NJ  125000.0  Data_Scientist
# 28                           Mount Laurel, NJ  125000.0  Data_Scientist
#
#       Experience
# 0   Senior_level
# 1   Senior_level
# 2   Senior_level
# 3   Senior_level
# 4   Senior_level
# 5   Senior_level
# 6   Senior_level
# 7   Senior_level
# 8   Senior_level
# 9   Senior_level
# 10  Senior_level
# 11  Senior_level
# 12  Senior_level
# 13  Senior_level
# 14  Senior_level
# 15  Senior_level
# 16  Senior_level
# 17  Senior_level
# 18  Senior_level
# 19  Senior_level
# 20  Senior_level
# 21  Senior_level
# 22  Senior_level
# 23  Senior_level
# 24  Senior_level
# 25  Senior_level
# 26  Senior_level
# 27  Senior_level
# 28  Senior_level

# %%
## Data_scientist_NY_140_entry


driver = webdriver.Chrome()
url = "https://www.indeed.com/jobs?q=%22Data+Scientist%22+$140,000%2B&l=New+York,+NY&radius=50&explvl=entry_level&limit=100"
driver.get(url)
# wait one second
sleep(1)
#grab the page source
html = driver.page_source
# BeautifulSoup it!
html = BeautifulSoup(html)
driver.close()

# I'm going to create my empty df first
import pandas as pd
dcarea_job1 = pd.DataFrame(columns=["Company_name"])
dcarea_job2 = pd.DataFrame(columns=["Location","Salary", "Title","Experience"])
# loop through each entry
for company in html.find_all('span', {'class':'company'}):
    name_comp = company.text
    dcarea_job1.loc[len(dcarea_job1)]=[name_comp]
    
for location in html.find_all('span', {'class':'location'}):
    loc_comp = location.text
    salary = 140000
    experience = "Entry_level"
    # try to find the number of bookings
    title = "Data_Scientist"
    dcarea_job2.loc[len(dcarea_job2)]=[loc_comp,salary,title,experience]

dcarea_job1['Company_name'] = dcarea_job1['Company_name'].str.replace('\n', '')
dcarea_job2['Location'] = dcarea_job2['Location'].str.replace('\n', '')

result_NY_140_entry = pd.concat([dcarea_job1, dcarea_job2], axis=1)

result_NY_140_entry

##Data_scientist_NY_140_mid


driver = webdriver.Chrome()
url = "https://www.indeed.com/jobs?q=%22Data+Scientist%22+$140,000%2B&l=New+York,+NY&radius=50&explvl=mid_level&limit=100"
driver.get(url)
# wait one second
sleep(1)
#grab the page source
html = driver.page_source
# BeautifulSoup it!
html = BeautifulSoup(html)
driver.close()

# I'm going to create my empty df first
import pandas as pd
dcarea_job1 = pd.DataFrame(columns=["Company_name"])
dcarea_job2 = pd.DataFrame(columns=["Location","Salary", "Title","Experience"])
# loop through each entry
for company in html.find_all('span', {'class':'company'}):
    name_comp = company.text
    dcarea_job1.loc[len(dcarea_job1)]=[name_comp]
    
for location in html.find_all('span', {'class':'location'}):
    loc_comp = location.text
    salary = 140000
    experience = "Mid_level"
    # try to find the number of bookings
    title = "Data_Scientist"
    dcarea_job2.loc[len(dcarea_job2)]=[loc_comp,salary,title,experience]

dcarea_job1['Company_name'] = dcarea_job1['Company_name'].str.replace('\n', '')
dcarea_job2['Location'] = dcarea_job2['Location'].str.replace('\n', '')

result_NY_140_mid = pd.concat([dcarea_job1, dcarea_job2], axis=1)

result_NY_140_mid

##Data_scientist_NY_140_senior

driver = webdriver.Chrome()
url = "https://www.indeed.com/jobs?q=%22Data+Scientist%22+$140,000%2B&l=New+York,+NY&radius=50&explvl=senior_level&limit=100"
driver.get(url)
# wait one second
sleep(1)
#grab the page source
html = driver.page_source
# BeautifulSoup it!
html = BeautifulSoup(html)
driver.close()

# I'm going to create my empty df first
import pandas as pd
dcarea_job1 = pd.DataFrame(columns=["Company_name"])
dcarea_job2 = pd.DataFrame(columns=["Location","Salary", "Title","Experience"])
# loop through each entry
for company in html.find_all('span', {'class':'company'}):
    name_comp = company.text
    dcarea_job1.loc[len(dcarea_job1)]=[name_comp]
    
for location in html.find_all('span', {'class':'location'}):
    loc_comp = location.text
    salary = 140000
    experience = "Senior_level"
    # try to find the number of bookings
    title = "Data_Scientist"
    dcarea_job2.loc[len(dcarea_job2)]=[loc_comp,salary,title,experience]

dcarea_job1['Company_name'] = dcarea_job1['Company_name'].str.replace('\n', '')
dcarea_job2['Location'] = dcarea_job2['Location'].str.replace('\n', '')

result_NY_140_senior = pd.concat([dcarea_job1, dcarea_job2], axis=1)

result_NY_140_senior
# Out:
#                                Company_name  \
# 0                                   Harnham
# 1                                   TD Bank
# 2                        MLB Advanced Media
# 3                                   Averity
# 4                                       AIG
# 5                                    Tumblr
# 6                                S&P GLOBAL
# 7                                   Harnham
# 8                         Rockstar New York
# 9                                   Harnham
# 10                    Big Cloud Recruitment
# 11                                      KCS
# 12                                  Averity
# 13                      Garrison Associates
# 14                                      AIG
# 15          Johnson & Johnson Services Inc.
# 16                                Accenture
# 17                The James Allen Companies
#
#                                      Location    Salary           Title  \
# 0                          New York, NY 10150  140000.0  Data_Scientist
# 1                            Mount Laurel, NJ  140000.0  Data_Scientist
# 2           New York, NY 10011 (Chelsea area)  140000.0  Data_Scientist
# 3                                New York, NY  140000.0  Data_Scientist
# 4                                New York, NY  140000.0  Data_Scientist
# 5                                New York, NY  140000.0  Data_Scientist
# 6   New York, NY 10002 (Lower East Side area)  140000.0  Data_Scientist
# 7                                New York, NY  140000.0  Data_Scientist
# 8                                New York, NY  140000.0  Data_Scientist
# 9                                New York, NY  140000.0  Data_Scientist
# 10                               New York, NY  140000.0  Data_Scientist
# 11                               New York, NY  140000.0  Data_Scientist
# 12                                  Union, NJ  140000.0  Data_Scientist
# 13     New York, NY 10110 (East Village area)  140000.0  Data_Scientist
# 14                               New York, NY  140000.0  Data_Scientist
# 15                            Bridgewater, NJ  140000.0  Data_Scientist
# 16          New York, NY 10011 (Chelsea area)  140000.0  Data_Scientist
# 17                            Jersey City, NJ  140000.0  Data_Scientist
#
#       Experience
# 0   Senior_level
# 1   Senior_level
# 2   Senior_level
# 3   Senior_level
# 4   Senior_level
# 5   Senior_level
# 6   Senior_level
# 7   Senior_level
# 8   Senior_level
# 9   Senior_level
# 10  Senior_level
# 11  Senior_level
# 12  Senior_level
# 13  Senior_level
# 14  Senior_level
# 15  Senior_level
# 16  Senior_level
# 17  Senior_level

# %% [markdown]
# ## San francisco

# %%
## Data_scientist_SF_90_entry

driver = webdriver.Chrome()
url = "https://www.indeed.com/jobs?q=%22Data+Scientist%22+$90,000&l=San+Francisco,+CA&radius=50&explvl=entry_level&limit=100"
driver.get(url)
# wait one second
sleep(1)
#grab the page source
html = driver.page_source
# BeautifulSoup it!
html = BeautifulSoup(html)
driver.close()

# I'm going to create my empty df first
import pandas as pd
dcarea_job1 = pd.DataFrame(columns=["Company_name"])
dcarea_job2 = pd.DataFrame(columns=["Location","Salary", "Title","Experience"])
# loop through each entry
for company in html.find_all('span', {'class':'company'}):
    name_comp = company.text
    dcarea_job1.loc[len(dcarea_job1)]=[name_comp]
    
for location in html.find_all('span', {'class':'location'}):
    loc_comp = location.text
    salary = 90000
    experience = "Entry_level"
    # try to find the number of bookings
    title = "Data_Scientist"
    dcarea_job2.loc[len(dcarea_job2)]=[loc_comp,salary,title,experience]

dcarea_job1['Company_name'] = dcarea_job1['Company_name'].str.replace('\n', '')
dcarea_job2['Location'] = dcarea_job2['Location'].str.replace('\n', '')

result_SF_90_entry = pd.concat([dcarea_job1, dcarea_job2], axis=1)

result_SF_90_entry

## Data_scientist_SF_90_mid

driver = webdriver.Chrome()
url = "https://www.indeed.com/jobs?q=%22Data+Scientist%22+$90,000&l=San+Francisco,+CA&radius=50&explvl=mid_level&limit=100"
driver.get(url)
# wait one second
sleep(1)
#grab the page source
html = driver.page_source
# BeautifulSoup it!
html = BeautifulSoup(html)
driver.close()

# I'm going to create my empty df first
import pandas as pd
dcarea_job1 = pd.DataFrame(columns=["Company_name"])
dcarea_job2 = pd.DataFrame(columns=["Location","Salary", "Title","Experience"])
# loop through each entry
for company in html.find_all('span', {'class':'company'}):
    name_comp = company.text
    dcarea_job1.loc[len(dcarea_job1)]=[name_comp]
    
for location in html.find_all('span', {'class':'location'}):
    loc_comp = location.text
    salary = 90000
    experience = "Mid_level"
    # try to find the number of bookings
    title = "Data_Scientist"
    dcarea_job2.loc[len(dcarea_job2)]=[loc_comp,salary,title,experience]

dcarea_job1['Company_name'] = dcarea_job1['Company_name'].str.replace('\n', '')
dcarea_job2['Location'] = dcarea_job2['Location'].str.replace('\n', '')

result_SF_90_mid = pd.concat([dcarea_job1, dcarea_job2], axis=1)

result_SF_90_mid

## Data_scientist_SF_90_senior

driver = webdriver.Chrome()
url = "https://www.indeed.com/jobs?q=%22Data+Scientist%22+$90,000&l=San+Francisco,+CA&radius=50&explvl=senior_level&limit=100"
driver.get(url)
# wait one second
sleep(1)
#grab the page source
html = driver.page_source
# BeautifulSoup it!
html = BeautifulSoup(html)
driver.close()

# I'm going to create my empty df first
import pandas as pd
dcarea_job1 = pd.DataFrame(columns=["Company_name"])
dcarea_job2 = pd.DataFrame(columns=["Location","Salary", "Title","Experience"])
# loop through each entry
for company in html.find_all('span', {'class':'company'}):
    name_comp = company.text
    dcarea_job1.loc[len(dcarea_job1)]=[name_comp]
    
for location in html.find_all('span', {'class':'location'}):
    loc_comp = location.text
    salary = 90000
    experience = "Senior_level"
    # try to find the number of bookings
    title = "Data_Scientist"
    dcarea_job2.loc[len(dcarea_job2)]=[loc_comp,salary,title,experience]

dcarea_job1['Company_name'] = dcarea_job1['Company_name'].str.replace('\n', '')
dcarea_job2['Location'] = dcarea_job2['Location'].str.replace('\n', '')

result_SF_90_senior = pd.concat([dcarea_job1, dcarea_job2], axis=1)

result_SF_90_senior
# Out:
#                                          Company_name  \
# 0                                           Genentech
# 1                                            Datameer
# 2                                     iSoft Solutions
# 3                                               Hired
# 4                                           Genentech
# 5                                        Apixio, Inc.
# 6                                     CA Technologies
# 7                                            Symantec
# 8                                          GE Careers
# 9                                          GE Careers
# 10                                        MachineZone
# 11                                          Sigmaways
# 12                                             Fitbit
# 13                                         Change.org
# 14                                           LeanTaaS
# 15                                         TEKsystems
# 16                                 Gap Inc. Corporate
# 17                                Cisco Systems, Inc.
# 18                              Workbridge Associates
# 19                              Bayone Solutions Inc.
# 20                                   InfoVision, Inc.
# 21                                         Quantifind
# 22                                               eBay
# 23                                             Square
# 24                                    Thomson Reuters
# 25                                               YuMe
# 26                                         Proofpoint
# 27                                         Demandbase
# 28                                         Move, Inc.
# 29                                           TrialPay
# ..                                                ...
# 55                                               IMVU
# 56                                              Chegg
# 57                                            Netflix
# 58                                          Capgemini
# 59                                Cisco Systems, Inc.
# 60                                            Dropbox
# 61                                             Intuit
# 62                                Pandora Media, Inc.
# 63                                    Electronic Arts
# 64                                     Apartment List
# 65                                             EOS DA
# 66                                          Accenture
# 67      Redfish Technology - High Tech Executive R...
# 68                                          Microsoft
# 69                                       NTT Security
# 70                                             Oracle
# 71                           Elevate Recruiting Group
# 72                                     Lyft Corporate
# 73                                           Datameer
# 74                    Risk Management Solutions (RMS)
# 75                                        Yahoo! Inc.
# 76                                          Accenture
# 77                               Oxford International
# 78                                         GE Careers
# 79                                          StyleSeat
# 80                             Quality IT Source, LLC
# 81                                     Charles Schwab
# 82                                         GE Careers
# 83                                          Accenture
# 84                                           Zendrive
#
#                                              Location   Salary  \
# 0                             South San Francisco, CA  90000.0
# 1                                   San Francisco, CA  90000.0
# 2                                   San Francisco, CA  90000.0
# 3                                   San Francisco, CA  90000.0
# 4                             South San Francisco, CA  90000.0
# 5                                       San Mateo, CA  90000.0
# 6                                     Santa Clara, CA  90000.0
# 7                                   Mountain View, CA  90000.0
# 8                                 San Ramon, CA 94583  90000.0
# 9                                 San Ramon, CA 94583  90000.0
# 10                                      Palo Alto, CA  90000.0
# 11                                      Palo Alto, CA  90000.0
# 12  San Francisco, CA 94105 (Financial District area)  90000.0
# 13     San Francisco, CA 94103 (South Of Market area)  90000.0
# 14                                    Santa Clara, CA  90000.0
# 15     San Francisco, CA 94103 (South Of Market area)  90000.0
# 16                                  San Francisco, CA  90000.0
# 17                                       San Jose, CA  90000.0
# 18  San Francisco, CA 94105 (Financial District area)  90000.0
# 19                                  San Francisco, CA  90000.0
# 20                                       San Jose, CA  90000.0
# 21                                     Menlo Park, CA  90000.0
# 22                                       San Jose, CA  90000.0
# 23     San Francisco, CA 94103 (South Of Market area)  90000.0
# 24                                  San Francisco, CA  90000.0
# 25                             Redwood City, CA 94063  90000.0
# 26                                Sunnyvale, CA 94089  90000.0
# 27                                  San Francisco, CA  90000.0
# 28                                    Santa Clara, CA  90000.0
# 29                                  Mountain View, CA  90000.0
# ..                                                ...      ...
# 55                                   Redwood City, CA  90000.0
# 56                                  San Francisco, CA  90000.0
# 57                                      Los Gatos, CA  90000.0
# 58                            South San Francisco, CA  90000.0
# 59                                       San Jose, CA  90000.0
# 60                                  San Francisco, CA  90000.0
# 61                            Mountain View, CA 94039  90000.0
# 62                                        Oakland, CA  90000.0
# 63                             Redwood City, CA 94065  90000.0
# 64                                  San Francisco, CA  90000.0
# 65                                     Menlo Park, CA  90000.0
# 66  San Francisco, CA 94105 (Financial District area)  90000.0
# 67                                  San Francisco, CA  90000.0
# 68                                  San Francisco, CA  90000.0
# 69  Palo Alto, CA 94303 (Duveneck-Saint Francis area)  90000.0
# 70                                 Redwood Shores, CA  90000.0
# 71                                      Palo Alto, CA  90000.0
# 72                                  San Francisco, CA  90000.0
# 73     San Francisco, CA 94103 (South Of Market area)  90000.0
# 74                                         Newark, CA  90000.0
# 75                                      Sunnyvale, CA  90000.0
# 76  San Francisco, CA 94105 (Financial District area)  90000.0
# 77                                      Sunnyvale, CA  90000.0
# 78                                San Ramon, CA 94583  90000.0
# 79                                  San Francisco, CA  90000.0
# 80                                  San Francisco, CA  90000.0
# 81            San Francisco, CA 94102 (Downtown area)  90000.0
# 82                                San Ramon, CA 94583  90000.0
# 83  San Francisco, CA 94105 (Financial District area)  90000.0
# 84                                  San Francisco, CA  90000.0
#
#              Title    Experience
# 0   Data_Scientist  Senior_level
# 1   Data_Scientist  Senior_level
# 2   Data_Scientist  Senior_level
# 3   Data_Scientist  Senior_level
# 4   Data_Scientist  Senior_level
# 5   Data_Scientist  Senior_level
# 6   Data_Scientist  Senior_level
# 7   Data_Scientist  Senior_level
# 8   Data_Scientist  Senior_level
# 9   Data_Scientist  Senior_level
# 10  Data_Scientist  Senior_level
# 11  Data_Scientist  Senior_level
# 12  Data_Scientist  Senior_level
# 13  Data_Scientist  Senior_level
# 14  Data_Scientist  Senior_level
# 15  Data_Scientist  Senior_level
# 16  Data_Scientist  Senior_level
# 17  Data_Scientist  Senior_level
# 18  Data_Scientist  Senior_level
# 19  Data_Scientist  Senior_level
# 20  Data_Scientist  Senior_level
# 21  Data_Scientist  Senior_level
# 22  Data_Scientist  Senior_level
# 23  Data_Scientist  Senior_level
# 24  Data_Scientist  Senior_level
# 25  Data_Scientist  Senior_level
# 26  Data_Scientist  Senior_level
# 27  Data_Scientist  Senior_level
# 28  Data_Scientist  Senior_level
# 29  Data_Scientist  Senior_level
# ..             ...           ...
# 55  Data_Scientist  Senior_level
# 56  Data_Scientist  Senior_level
# 57  Data_Scientist  Senior_level
# 58  Data_Scientist  Senior_level
# 59  Data_Scientist  Senior_level
# 60  Data_Scientist  Senior_level
# 61  Data_Scientist  Senior_level
# 62  Data_Scientist  Senior_level
# 63  Data_Scientist  Senior_level
# 64  Data_Scientist  Senior_level
# 65  Data_Scientist  Senior_level
# 66  Data_Scientist  Senior_level
# 67  Data_Scientist  Senior_level
# 68  Data_Scientist  Senior_level
# 69  Data_Scientist  Senior_level
# 70  Data_Scientist  Senior_level
# 71  Data_Scientist  Senior_level
# 72  Data_Scientist  Senior_level
# 73  Data_Scientist  Senior_level
# 74  Data_Scientist  Senior_level
# 75  Data_Scientist  Senior_level
# 76  Data_Scientist  Senior_level
# 77  Data_Scientist  Senior_level
# 78  Data_Scientist  Senior_level
# 79  Data_Scientist  Senior_level
# 80  Data_Scientist  Senior_level
# 81  Data_Scientist  Senior_level
# 82  Data_Scientist  Senior_level
# 83  Data_Scientist  Senior_level
# 84  Data_Scientist  Senior_level
#
# [85 rows x 5 columns]

# %%
## Data_scientist_sf_105_entry

driver = webdriver.Chrome()
url = "https://www.indeed.com/jobs?q=%22Data+Scientist%22+$105,000&l=San+Francisco,+CA&radius=50&explvl=entry_level&limit=100"
driver.get(url)
# wait one second
sleep(1)
#grab the page source
html = driver.page_source
# BeautifulSoup it!
html = BeautifulSoup(html)
driver.close()

# I'm going to create my empty df first
import pandas as pd
dcarea_job1 = pd.DataFrame(columns=["Company_name"])
dcarea_job2 = pd.DataFrame(columns=["Location","Salary", "Title","Experience"])
# loop through each entry
for company in html.find_all('span', {'class':'company'}):
    name_comp = company.text
    dcarea_job1.loc[len(dcarea_job1)]=[name_comp]
    
for location in html.find_all('span', {'class':'location'}):
    loc_comp = location.text
    salary = 105000
    experience = "Entry_level"
    # try to find the number of bookings
    title = "Data_Scientist"
    dcarea_job2.loc[len(dcarea_job2)]=[loc_comp,salary,title,experience]

dcarea_job1['Company_name'] = dcarea_job1['Company_name'].str.replace('\n', '')
dcarea_job2['Location'] = dcarea_job2['Location'].str.replace('\n', '')

result_SF_105_entry = pd.concat([dcarea_job1, dcarea_job2], axis=1)

result_SF_105_entry

## Data_scientist_SF_105_mid

driver = webdriver.Chrome()
url = "https://www.indeed.com/jobs?q=%22Data+Scientist%22+$105,000&l=San+Francisco,+CA&radius=50&explvl=mid_level&limit=100"
driver.get(url)
# wait one second
sleep(1)
#grab the page source
html = driver.page_source
# BeautifulSoup it!
html = BeautifulSoup(html)
driver.close()

# I'm going to create my empty df first
import pandas as pd
dcarea_job1 = pd.DataFrame(columns=["Company_name"])
dcarea_job2 = pd.DataFrame(columns=["Location","Salary", "Title","Experience"])
# loop through each entry
for company in html.find_all('span', {'class':'company'}):
    name_comp = company.text
    dcarea_job1.loc[len(dcarea_job1)]=[name_comp]
    
for location in html.find_all('span', {'class':'location'}):
    loc_comp = location.text
    salary = 105000
    experience = "Mid_level"
    # try to find the number of bookings
    title = "Data_Scientist"
    dcarea_job2.loc[len(dcarea_job2)]=[loc_comp,salary,title,experience]

dcarea_job1['Company_name'] = dcarea_job1['Company_name'].str.replace('\n', '')
dcarea_job2['Location'] = dcarea_job2['Location'].str.replace('\n', '')

result_SF_105_mid = pd.concat([dcarea_job1, dcarea_job2], axis=1)

result_SF_105_mid

## Data_scientist_SF_105_senior

driver = webdriver.Chrome()
url = "https://www.indeed.com/jobs?q=%22Data+Scientist%22+$105,000&l=San+Francisco,+CA&radius=50&explvl=senior_level&limit=100"
driver.get(url)
# wait one second
sleep(1)
#grab the page source
html = driver.page_source
# BeautifulSoup it!
html = BeautifulSoup(html)
driver.close()

# I'm going to create my empty df first
import pandas as pd
dcarea_job1 = pd.DataFrame(columns=["Company_name"])
dcarea_job2 = pd.DataFrame(columns=["Location","Salary", "Title","Experience"])
# loop through each entry
for company in html.find_all('span', {'class':'company'}):
    name_comp = company.text
    dcarea_job1.loc[len(dcarea_job1)]=[name_comp]
    
for location in html.find_all('span', {'class':'location'}):
    loc_comp = location.text
    salary = 105000
    experience = "Senior_level"
    # try to find the number of bookings
    title = "Data_Scientist"
    dcarea_job2.loc[len(dcarea_job2)]=[loc_comp,salary,title,experience]

dcarea_job1['Company_name'] = dcarea_job1['Company_name'].str.replace('\n', '')
dcarea_job2['Location'] = dcarea_job2['Location'].str.replace('\n', '')

result_SF_105_senior = pd.concat([dcarea_job1, dcarea_job2], axis=1)

result_SF_105_senior
# Out:
#                                          Company_name  \
# 0                                           Genentech
# 1                                            Datameer
# 2                                     iSoft Solutions
# 3                                               Hired
# 4                                        Apixio, Inc.
# 5                                           Genentech
# 6                                            Symantec
# 7                                          GE Careers
# 8                                          GE Careers
# 9                                         MachineZone
# 10                                          Sigmaways
# 11                                         Change.org
# 12                                           LeanTaaS
# 13                                             Fitbit
# 14                                         TEKsystems
# 15                                 Gap Inc. Corporate
# 16                                Cisco Systems, Inc.
# 17                                   InfoVision, Inc.
# 18                              Workbridge Associates
# 19                              Bayone Solutions Inc.
# 20                                               eBay
# 21                                         Quantifind
# 22                                             Square
# 23                                               YuMe
# 24                                         Demandbase
# 25                                         Proofpoint
# 26                                           Datameer
# 27                                         Move, Inc.
# 28                                           TrialPay
# 29                        Samsung Electronics America
# ..                                                ...
# 42                                               Arka
# 43                                   All-In Analytics
# 44                              InsideSales.com, Inc.
# 45                                              Ten-X
# 46                                          Capgemini
# 47                                              Chegg
# 48                                 Jobspring Partners
# 49                                            Netflix
# 50                                               IMVU
# 51                                            Dropbox
# 52                                             Intuit
# 53                                     Apartment List
# 54                                    Electronic Arts
# 55                                          Accenture
# 56                                          Microsoft
# 57                                             EOS DA
# 58                                Cisco Systems, Inc.
# 59      Redfish Technology - High Tech Executive R...
# 60                                           Datameer
# 61                                             Oracle
# 62                                       NTT Security
# 63                                     Lyft Corporate
# 64                           Elevate Recruiting Group
# 65                                          Accenture
# 66                                         GE Careers
# 67                                          StyleSeat
# 68                             Quality IT Source, LLC
# 69                                         GE Careers
# 70                                          Accenture
# 71                                           Zendrive
#
#                                              Location    Salary  \
# 0                             South San Francisco, CA  105000.0
# 1                                   San Francisco, CA  105000.0
# 2                                   San Francisco, CA  105000.0
# 3                                   San Francisco, CA  105000.0
# 4                                       San Mateo, CA  105000.0
# 5                             South San Francisco, CA  105000.0
# 6                                   Mountain View, CA  105000.0
# 7                                 San Ramon, CA 94583  105000.0
# 8                                 San Ramon, CA 94583  105000.0
# 9                                       Palo Alto, CA  105000.0
# 10                                      Palo Alto, CA  105000.0
# 11     San Francisco, CA 94103 (South Of Market area)  105000.0
# 12                                    Santa Clara, CA  105000.0
# 13  San Francisco, CA 94105 (Financial District area)  105000.0
# 14     San Francisco, CA 94103 (South Of Market area)  105000.0
# 15                                  San Francisco, CA  105000.0
# 16                                       San Jose, CA  105000.0
# 17                                       San Jose, CA  105000.0
# 18  San Francisco, CA 94105 (Financial District area)  105000.0
# 19                                  San Francisco, CA  105000.0
# 20                                       San Jose, CA  105000.0
# 21                                     Menlo Park, CA  105000.0
# 22     San Francisco, CA 94103 (South Of Market area)  105000.0
# 23                             Redwood City, CA 94063  105000.0
# 24                                  San Francisco, CA  105000.0
# 25                                Sunnyvale, CA 94089  105000.0
# 26     San Francisco, CA 94103 (South Of Market area)  105000.0
# 27                                    Santa Clara, CA  105000.0
# 28                                  Mountain View, CA  105000.0
# 29                                  Mountain View, CA  105000.0
# ..                                                ...       ...
# 42                                  San Francisco, CA  105000.0
# 43                                  San Francisco, CA  105000.0
# 44                                      San Mateo, CA  105000.0
# 45                                        Belmont, CA  105000.0
# 46                            South San Francisco, CA  105000.0
# 47                              Santa Clara, CA 95054  105000.0
# 48                 San Jose, CA 95113 (Downtown area)  105000.0
# 49                                      Los Gatos, CA  105000.0
# 50                                   Redwood City, CA  105000.0
# 51                                  San Francisco, CA  105000.0
# 52                            Mountain View, CA 94039  105000.0
# 53                                  San Francisco, CA  105000.0
# 54                             Redwood City, CA 94065  105000.0
# 55  San Francisco, CA 94105 (Financial District area)  105000.0
# 56                                  San Francisco, CA  105000.0
# 57                                     Menlo Park, CA  105000.0
# 58                                       San Jose, CA  105000.0
# 59                                  San Francisco, CA  105000.0
# 60     San Francisco, CA 94103 (South Of Market area)  105000.0
# 61                                 Redwood Shores, CA  105000.0
# 62  Palo Alto, CA 94303 (Duveneck-Saint Francis area)  105000.0
# 63                                  San Francisco, CA  105000.0
# 64                                      Palo Alto, CA  105000.0
# 65  San Francisco, CA 94105 (Financial District area)  105000.0
# 66                                San Ramon, CA 94583  105000.0
# 67                                  San Francisco, CA  105000.0
# 68                                  San Francisco, CA  105000.0
# 69                                San Ramon, CA 94583  105000.0
# 70  San Francisco, CA 94105 (Financial District area)  105000.0
# 71                                  San Francisco, CA  105000.0
#
#              Title    Experience
# 0   Data_Scientist  Senior_level
# 1   Data_Scientist  Senior_level
# 2   Data_Scientist  Senior_level
# 3   Data_Scientist  Senior_level
# 4   Data_Scientist  Senior_level
# 5   Data_Scientist  Senior_level
# 6   Data_Scientist  Senior_level
# 7   Data_Scientist  Senior_level
# 8   Data_Scientist  Senior_level
# 9   Data_Scientist  Senior_level
# 10  Data_Scientist  Senior_level
# 11  Data_Scientist  Senior_level
# 12  Data_Scientist  Senior_level
# 13  Data_Scientist  Senior_level
# 14  Data_Scientist  Senior_level
# 15  Data_Scientist  Senior_level
# 16  Data_Scientist  Senior_level
# 17  Data_Scientist  Senior_level
# 18  Data_Scientist  Senior_level
# 19  Data_Scientist  Senior_level
# 20  Data_Scientist  Senior_level
# 21  Data_Scientist  Senior_level
# 22  Data_Scientist  Senior_level
# 23  Data_Scientist  Senior_level
# 24  Data_Scientist  Senior_level
# 25  Data_Scientist  Senior_level
# 26  Data_Scientist  Senior_level
# 27  Data_Scientist  Senior_level
# 28  Data_Scientist  Senior_level
# 29  Data_Scientist  Senior_level
# ..             ...           ...
# 42  Data_Scientist  Senior_level
# 43  Data_Scientist  Senior_level
# 44  Data_Scientist  Senior_level
# 45  Data_Scientist  Senior_level
# 46  Data_Scientist  Senior_level
# 47  Data_Scientist  Senior_level
# 48  Data_Scientist  Senior_level
# 49  Data_Scientist  Senior_level
# 50  Data_Scientist  Senior_level
# 51  Data_Scientist  Senior_level
# 52  Data_Scientist  Senior_level
# 53  Data_Scientist  Senior_level
# 54  Data_Scientist  Senior_level
# 55  Data_Scientist  Senior_level
# 56  Data_Scientist  Senior_level
# 57  Data_Scientist  Senior_level
# 58  Data_Scientist  Senior_level
# 59  Data_Scientist  Senior_level
# 60  Data_Scientist  Senior_level
# 61  Data_Scientist  Senior_level
# 62  Data_Scientist  Senior_level
# 63  Data_Scientist  Senior_level
# 64  Data_Scientist  Senior_level
# 65  Data_Scientist  Senior_level
# 66  Data_Scientist  Senior_level
# 67  Data_Scientist  Senior_level
# 68  Data_Scientist  Senior_level
# 69  Data_Scientist  Senior_level
# 70  Data_Scientist  Senior_level
# 71  Data_Scientist  Senior_level
#
# [72 rows x 5 columns]

# %%
## Data_scientist_SF_115_entry

driver = webdriver.Chrome()
url = "https://www.indeed.com/jobs?q=%22Data+Scientist%22+$115,000&l=San+Francisco,+CA&radius=50&explvl=entry_level&limit=100"
driver.get(url)
# wait one second
sleep(1)
#grab the page source
html = driver.page_source
# BeautifulSoup it!
html = BeautifulSoup(html)
driver.close()

# I'm going to create my empty df first
import pandas as pd
dcarea_job1 = pd.DataFrame(columns=["Company_name"])
dcarea_job2 = pd.DataFrame(columns=["Location","Salary", "Title","Experience"])
# loop through each entry
for company in html.find_all('span', {'class':'company'}):
    name_comp = company.text
    dcarea_job1.loc[len(dcarea_job1)]=[name_comp]
    
for location in html.find_all('span', {'class':'location'}):
    loc_comp = location.text
    salary = 115000
    experience = "Entry_level"
    # try to find the number of bookings
    title = "Data_Scientist"
    dcarea_job2.loc[len(dcarea_job2)]=[loc_comp,salary,title,experience]

dcarea_job1['Company_name'] = dcarea_job1['Company_name'].str.replace('\n', '')
dcarea_job2['Location'] = dcarea_job2['Location'].str.replace('\n', '')

result_SF_115_entry = pd.concat([dcarea_job1, dcarea_job2], axis=1)

result_SF_115_entry

## Data_scientist_SF_115_mid

driver = webdriver.Chrome()
url = "https://www.indeed.com/jobs?q=%22Data+Scientist%22+$115,000&l=San+Francisco,+CA&radius=50&explvl=mid_level&limit=100"
driver.get(url)
# wait one second
sleep(1)
#grab the page source
html = driver.page_source
# BeautifulSoup it!
html = BeautifulSoup(html)
driver.close()

# I'm going to create my empty df first
import pandas as pd
dcarea_job1 = pd.DataFrame(columns=["Company_name"])
dcarea_job2 = pd.DataFrame(columns=["Location","Salary", "Title","Experience"])
# loop through each entry
for company in html.find_all('span', {'class':'company'}):
    name_comp = company.text
    dcarea_job1.loc[len(dcarea_job1)]=[name_comp]
    
for location in html.find_all('span', {'class':'location'}):
    loc_comp = location.text
    salary = 115000
    experience = "Mid_level"
    # try to find the number of bookings
    title = "Data_Scientist"
    dcarea_job2.loc[len(dcarea_job2)]=[loc_comp,salary,title,experience]

dcarea_job1['Company_name'] = dcarea_job1['Company_name'].str.replace('\n', '')
dcarea_job2['Location'] = dcarea_job2['Location'].str.replace('\n', '')

result_SF_115_mid = pd.concat([dcarea_job1, dcarea_job2], axis=1)

result_SF_115_mid

## Data_scientist_SF_115_senior

driver = webdriver.Chrome()
url = "https://www.indeed.com/jobs?q=%22Data+Scientist%22+$115,000&l=San+Francisco,+CA&radius=50&explvl=senior_level&limit=100"
driver.get(url)
# wait one second
sleep(1)
#grab the page source
html = driver.page_source
# BeautifulSoup it!
html = BeautifulSoup(html)
driver.close()

# I'm going to create my empty df first
import pandas as pd
dcarea_job1 = pd.DataFrame(columns=["Company_name"])
dcarea_job2 = pd.DataFrame(columns=["Location","Salary", "Title","Experience"])
# loop through each entry
for company in html.find_all('span', {'class':'company'}):
    name_comp = company.text
    dcarea_job1.loc[len(dcarea_job1)]=[name_comp]
    
for location in html.find_all('span', {'class':'location'}):
    loc_comp = location.text
    salary = 115000
    experience = "Senior_level"
    # try to find the number of bookings
    title = "Data_Scientist"
    dcarea_job2.loc[len(dcarea_job2)]=[loc_comp,salary,title,experience]

dcarea_job1['Company_name'] = dcarea_job1['Company_name'].str.replace('\n', '')
dcarea_job2['Location'] = dcarea_job2['Location'].str.replace('\n', '')

result_SF_115_senior = pd.concat([dcarea_job1, dcarea_job2], axis=1)

result_SF_115_senior
# Out:
#                                          Company_name  \
# 0                                            Datameer
# 1                                     iSoft Solutions
# 2                                               Hired
# 3                                        Apixio, Inc.
# 4                                            Symantec
# 5                                          GE Careers
# 6                                          GE Careers
# 7                                         MachineZone
# 8                                           Sigmaways
# 9                                              Fitbit
# 10                                         Change.org
# 11                                           LeanTaaS
# 12                                         TEKsystems
# 13                                 Gap Inc. Corporate
# 14                                Cisco Systems, Inc.
# 15                              Workbridge Associates
# 16                              Bayone Solutions Inc.
# 17                                   InfoVision, Inc.
# 18                                         Quantifind
# 19                                               eBay
# 20                                             Square
# 21                                         Proofpoint
# 22                                         Demandbase
# 23                                         Move, Inc.
# 24                                           TrialPay
# 25                                           Datameer
# 26                              Workbridge Associates
# 27                                              Chegg
# 28                                            Coupang
# 29                                            Netflix
# ..                                                ...
# 32                                            Netflix
# 33                                            SanDisk
# 34                                               BOLD
# 35                        Samsung Electronics America
# 36                                   All-In Analytics
# 37                              InsideSales.com, Inc.
# 38                                              Ten-X
# 39                                           Ancestry
# 40                                               Arka
# 41                                              Chegg
# 42                                 Jobspring Partners
# 43                                            Netflix
# 44                                          Capgemini
# 45                                Cisco Systems, Inc.
# 46                                            Dropbox
# 47                                             Intuit
# 48                                    Electronic Arts
# 49                                     Apartment List
# 50                                             EOS DA
# 51                                          Accenture
# 52      Redfish Technology - High Tech Executive R...
# 53                                       NTT Security
# 54                                     Lyft Corporate
# 55                                           Datameer
# 56                                          Accenture
# 57                                         GE Careers
# 58                                          StyleSeat
# 59                             Quality IT Source, LLC
# 60                                         GE Careers
# 61                                          Accenture
#
#                                              Location    Salary  \
# 0                                   San Francisco, CA  115000.0
# 1                                   San Francisco, CA  115000.0
# 2                                   San Francisco, CA  115000.0
# 3                                       San Mateo, CA  115000.0
# 4                                   Mountain View, CA  115000.0
# 5                                 San Ramon, CA 94583  115000.0
# 6                                 San Ramon, CA 94583  115000.0
# 7                                       Palo Alto, CA  115000.0
# 8                                       Palo Alto, CA  115000.0
# 9   San Francisco, CA 94105 (Financial District area)  115000.0
# 10     San Francisco, CA 94103 (South Of Market area)  115000.0
# 11                                    Santa Clara, CA  115000.0
# 12     San Francisco, CA 94103 (South Of Market area)  115000.0
# 13                                  San Francisco, CA  115000.0
# 14                                       San Jose, CA  115000.0
# 15  San Francisco, CA 94105 (Financial District area)  115000.0
# 16                                  San Francisco, CA  115000.0
# 17                                       San Jose, CA  115000.0
# 18                                     Menlo Park, CA  115000.0
# 19                                       San Jose, CA  115000.0
# 20     San Francisco, CA 94103 (South Of Market area)  115000.0
# 21                                Sunnyvale, CA 94089  115000.0
# 22                                  San Francisco, CA  115000.0
# 23                                    Santa Clara, CA  115000.0
# 24                                  Mountain View, CA  115000.0
# 25     San Francisco, CA 94103 (South Of Market area)  115000.0
# 26                                  San Francisco, CA  115000.0
# 27                                  San Francisco, CA  115000.0
# 28                                      Palo Alto, CA  115000.0
# 29                                      Los Gatos, CA  115000.0
# ..                                                ...       ...
# 32                                      Los Gatos, CA  115000.0
# 33                                       Milpitas, CA  115000.0
# 34                                  San Francisco, CA  115000.0
# 35                                  Mountain View, CA  115000.0
# 36                                  San Francisco, CA  115000.0
# 37                                      San Mateo, CA  115000.0
# 38                                        Belmont, CA  115000.0
# 39                                  San Francisco, CA  115000.0
# 40                                  San Francisco, CA  115000.0
# 41                              Santa Clara, CA 95054  115000.0
# 42                 San Jose, CA 95113 (Downtown area)  115000.0
# 43                                      Los Gatos, CA  115000.0
# 44                            South San Francisco, CA  115000.0
# 45                                       San Jose, CA  115000.0
# 46                                  San Francisco, CA  115000.0
# 47                            Mountain View, CA 94039  115000.0
# 48                             Redwood City, CA 94065  115000.0
# 49                                  San Francisco, CA  115000.0
# 50                                     Menlo Park, CA  115000.0
# 51  San Francisco, CA 94105 (Financial District area)  115000.0
# 52                                  San Francisco, CA  115000.0
# 53  Palo Alto, CA 94303 (Duveneck-Saint Francis area)  115000.0
# 54                                  San Francisco, CA  115000.0
# 55     San Francisco, CA 94103 (South Of Market area)  115000.0
# 56  San Francisco, CA 94105 (Financial District area)  115000.0
# 57                                San Ramon, CA 94583  115000.0
# 58                                  San Francisco, CA  115000.0
# 59                                  San Francisco, CA  115000.0
# 60                                San Ramon, CA 94583  115000.0
# 61  San Francisco, CA 94105 (Financial District area)  115000.0
#
#              Title    Experience
# 0   Data_Scientist  Senior_level
# 1   Data_Scientist  Senior_level
# 2   Data_Scientist  Senior_level
# 3   Data_Scientist  Senior_level
# 4   Data_Scientist  Senior_level
# 5   Data_Scientist  Senior_level
# 6   Data_Scientist  Senior_level
# 7   Data_Scientist  Senior_level
# 8   Data_Scientist  Senior_level
# 9   Data_Scientist  Senior_level
# 10  Data_Scientist  Senior_level
# 11  Data_Scientist  Senior_level
# 12  Data_Scientist  Senior_level
# 13  Data_Scientist  Senior_level
# 14  Data_Scientist  Senior_level
# 15  Data_Scientist  Senior_level
# 16  Data_Scientist  Senior_level
# 17  Data_Scientist  Senior_level
# 18  Data_Scientist  Senior_level
# 19  Data_Scientist  Senior_level
# 20  Data_Scientist  Senior_level
# 21  Data_Scientist  Senior_level
# 22  Data_Scientist  Senior_level
# 23  Data_Scientist  Senior_level
# 24  Data_Scientist  Senior_level
# 25  Data_Scientist  Senior_level
# 26  Data_Scientist  Senior_level
# 27  Data_Scientist  Senior_level
# 28  Data_Scientist  Senior_level
# 29  Data_Scientist  Senior_level
# ..             ...           ...
# 32  Data_Scientist  Senior_level
# 33  Data_Scientist  Senior_level
# 34  Data_Scientist  Senior_level
# 35  Data_Scientist  Senior_level
# 36  Data_Scientist  Senior_level
# 37  Data_Scientist  Senior_level
# 38  Data_Scientist  Senior_level
# 39  Data_Scientist  Senior_level
# 40  Data_Scientist  Senior_level
# 41  Data_Scientist  Senior_level
# 42  Data_Scientist  Senior_level
# 43  Data_Scientist  Senior_level
# 44  Data_Scientist  Senior_level
# 45  Data_Scientist  Senior_level
# 46  Data_Scientist  Senior_level
# 47  Data_Scientist  Senior_level
# 48  Data_Scientist  Senior_level
# 49  Data_Scientist  Senior_level
# 50  Data_Scientist  Senior_level
# 51  Data_Scientist  Senior_level
# 52  Data_Scientist  Senior_level
# 53  Data_Scientist  Senior_level
# 54  Data_Scientist  Senior_level
# 55  Data_Scientist  Senior_level
# 56  Data_Scientist  Senior_level
# 57  Data_Scientist  Senior_level
# 58  Data_Scientist  Senior_level
# 59  Data_Scientist  Senior_level
# 60  Data_Scientist  Senior_level
# 61  Data_Scientist  Senior_level
#
# [62 rows x 5 columns]

# %%
## Data_scientist_SF_125_entry

driver = webdriver.Chrome()
url = "https://www.indeed.com/jobs?q=%22Data+Scientist%22+$125,000&l=San+Francisco,+CA&radius=50&explvl=entry_level&limit=100"
driver.get(url)
# wait one second
sleep(1)
#grab the page source
html = driver.page_source
# BeautifulSoup it!
html = BeautifulSoup(html)
driver.close()

# I'm going to create my empty df first
import pandas as pd
dcarea_job1 = pd.DataFrame(columns=["Company_name"])
dcarea_job2 = pd.DataFrame(columns=["Location","Salary", "Title","Experience"])
# loop through each entry
for company in html.find_all('span', {'class':'company'}):
    name_comp = company.text
    dcarea_job1.loc[len(dcarea_job1)]=[name_comp]
    
for location in html.find_all('span', {'class':'location'}):
    loc_comp = location.text
    salary = 125000
    experience = "Entry_level"
    # try to find the number of bookings
    title = "Data_Scientist"
    dcarea_job2.loc[len(dcarea_job2)]=[loc_comp,salary,title,experience]

dcarea_job1['Company_name'] = dcarea_job1['Company_name'].str.replace('\n', '')
dcarea_job2['Location'] = dcarea_job2['Location'].str.replace('\n', '')

result_SF_125_entry = pd.concat([dcarea_job1, dcarea_job2], axis=1)

result_SF_125_entry

## Data_scientist_SF_125_mid

driver = webdriver.Chrome()
url = "https://www.indeed.com/jobs?q=%22Data+Scientist%22+$125,000&l=San+Francisco,+CA&radius=50&explvl=mid_level&limit=100"
driver.get(url)
# wait one second
sleep(1)
#grab the page source
html = driver.page_source
# BeautifulSoup it!
html = BeautifulSoup(html)
driver.close()

# I'm going to create my empty df first
import pandas as pd
dcarea_job1 = pd.DataFrame(columns=["Company_name"])
dcarea_job2 = pd.DataFrame(columns=["Location","Salary", "Title","Experience"])
# loop through each entry
for company in html.find_all('span', {'class':'company'}):
    name_comp = company.text
    dcarea_job1.loc[len(dcarea_job1)]=[name_comp]
    
for location in html.find_all('span', {'class':'location'}):
    loc_comp = location.text
    salary = 125000
    experience = "Mid_level"
    # try to find the number of bookings
    title = "Data_Scientist"
    dcarea_job2.loc[len(dcarea_job2)]=[loc_comp,salary,title,experience]

dcarea_job1['Company_name'] = dcarea_job1['Company_name'].str.replace('\n', '')
dcarea_job2['Location'] = dcarea_job2['Location'].str.replace('\n', '')

result_SF_125_mid = pd.concat([dcarea_job1, dcarea_job2], axis=1)

result_SF_125_mid

## Data_scientist_SF_125_senior

driver = webdriver.Chrome()
url = "https://www.indeed.com/jobs?q=%22Data+Scientist%22+$125,000&l=San+Francisco,+CA&radius=50&explvl=senior_level&limit=100"
driver.get(url)
# wait one second
sleep(1)
#grab the page source
html = driver.page_source
# BeautifulSoup it!
html = BeautifulSoup(html)
driver.close()

# I'm going to create my empty df first
import pandas as pd
dcarea_job1 = pd.DataFrame(columns=["Company_name"])
dcarea_job2 = pd.DataFrame(columns=["Location","Salary", "Title","Experience"])
# loop through each entry
for company in html.find_all('span', {'class':'company'}):
    name_comp = company.text
    dcarea_job1.loc[len(dcarea_job1)]=[name_comp]
    
for location in html.find_all('span', {'class':'location'}):
    loc_comp = location.text
    salary = 125000
    experience = "Senior_level"
    # try to find the number of bookings
    title = "Data_Scientist"
    dcarea_job2.loc[len(dcarea_job2)]=[loc_comp,salary,title,experience]

dcarea_job1['Company_name'] = dcarea_job1['Company_name'].str.replace('\n', '')
dcarea_job2['Location'] = dcarea_job2['Location'].str.replace('\n', '')

result_SF_125_senior = pd.concat([dcarea_job1, dcarea_job2], axis=1)

result_SF_125_senior
# Out:
#                                          Company_name  \
# 0                                            Datameer
# 1                                               Hired
# 2                                        Apixio, Inc.
# 3                                            Symantec
# 4                                          GE Careers
# 5                                          GE Careers
# 6                                           Sigmaways
# 7                                          Change.org
# 8                                            LeanTaaS
# 9                                          TEKsystems
# 10                                 Gap Inc. Corporate
# 11                                Cisco Systems, Inc.
# 12                                   InfoVision, Inc.
# 13                              Workbridge Associates
# 14                              Bayone Solutions Inc.
# 15                                               eBay
# 16                                             Square
# 17                                         Demandbase
# 18                                         Proofpoint
# 19                                           Datameer
# 20                                           TrialPay
# 21                                              Chegg
# 22                              Workbridge Associates
# 23                                            Netflix
# 24                                           Symantec
# 25                                              Adobe
# 26                                            Netflix
# 27                                               BOLD
# 28                                            SanDisk
# 29                                           Ancestry
# 30                                               Arka
# 31                                   All-In Analytics
# 32                              InsideSales.com, Inc.
# 33                                          Capgemini
# 34                                              Chegg
# 35                                 Jobspring Partners
# 36                                            Netflix
# 37                                            Dropbox
# 38                                             Intuit
# 39                                          Accenture
# 40                                             EOS DA
# 41                                Cisco Systems, Inc.
# 42      Redfish Technology - High Tech Executive R...
# 43                                           Datameer
# 44                                          Accenture
# 45                                         GE Careers
# 46                                          StyleSeat
# 47                                         GE Careers
# 48                                          Accenture
#
#                                              Location    Salary  \
# 0                                   San Francisco, CA  125000.0
# 1                                   San Francisco, CA  125000.0
# 2                                       San Mateo, CA  125000.0
# 3                                   Mountain View, CA  125000.0
# 4                                 San Ramon, CA 94583  125000.0
# 5                                 San Ramon, CA 94583  125000.0
# 6                                       Palo Alto, CA  125000.0
# 7      San Francisco, CA 94103 (South Of Market area)  125000.0
# 8                                     Santa Clara, CA  125000.0
# 9      San Francisco, CA 94103 (South Of Market area)  125000.0
# 10                                  San Francisco, CA  125000.0
# 11                                       San Jose, CA  125000.0
# 12                                       San Jose, CA  125000.0
# 13  San Francisco, CA 94105 (Financial District area)  125000.0
# 14                                  San Francisco, CA  125000.0
# 15                                       San Jose, CA  125000.0
# 16     San Francisco, CA 94103 (South Of Market area)  125000.0
# 17                                  San Francisco, CA  125000.0
# 18                                Sunnyvale, CA 94089  125000.0
# 19     San Francisco, CA 94103 (South Of Market area)  125000.0
# 20                                  Mountain View, CA  125000.0
# 21                                  San Francisco, CA  125000.0
# 22                                  San Francisco, CA  125000.0
# 23                                      Los Gatos, CA  125000.0
# 24                                  Mountain View, CA  125000.0
# 25                                       San Jose, CA  125000.0
# 26                                      Los Gatos, CA  125000.0
# 27                                  San Francisco, CA  125000.0
# 28                                       Milpitas, CA  125000.0
# 29                                  San Francisco, CA  125000.0
# 30                                  San Francisco, CA  125000.0
# 31                                  San Francisco, CA  125000.0
# 32                                      San Mateo, CA  125000.0
# 33                            South San Francisco, CA  125000.0
# 34                              Santa Clara, CA 95054  125000.0
# 35                 San Jose, CA 95113 (Downtown area)  125000.0
# 36                                      Los Gatos, CA  125000.0
# 37                                  San Francisco, CA  125000.0
# 38                            Mountain View, CA 94039  125000.0
# 39  San Francisco, CA 94105 (Financial District area)  125000.0
# 40                                     Menlo Park, CA  125000.0
# 41                                       San Jose, CA  125000.0
# 42                                  San Francisco, CA  125000.0
# 43     San Francisco, CA 94103 (South Of Market area)  125000.0
# 44  San Francisco, CA 94105 (Financial District area)  125000.0
# 45                                San Ramon, CA 94583  125000.0
# 46                                  San Francisco, CA  125000.0
# 47                                San Ramon, CA 94583  125000.0
# 48  San Francisco, CA 94105 (Financial District area)  125000.0
#
#              Title    Experience
# 0   Data_Scientist  Senior_level
# 1   Data_Scientist  Senior_level
# 2   Data_Scientist  Senior_level
# 3   Data_Scientist  Senior_level
# 4   Data_Scientist  Senior_level
# 5   Data_Scientist  Senior_level
# 6   Data_Scientist  Senior_level
# 7   Data_Scientist  Senior_level
# 8   Data_Scientist  Senior_level
# 9   Data_Scientist  Senior_level
# 10  Data_Scientist  Senior_level
# 11  Data_Scientist  Senior_level
# 12  Data_Scientist  Senior_level
# 13  Data_Scientist  Senior_level
# 14  Data_Scientist  Senior_level
# 15  Data_Scientist  Senior_level
# 16  Data_Scientist  Senior_level
# 17  Data_Scientist  Senior_level
# 18  Data_Scientist  Senior_level
# 19  Data_Scientist  Senior_level
# 20  Data_Scientist  Senior_level
# 21  Data_Scientist  Senior_level
# 22  Data_Scientist  Senior_level
# 23  Data_Scientist  Senior_level
# 24  Data_Scientist  Senior_level
# 25  Data_Scientist  Senior_level
# 26  Data_Scientist  Senior_level
# 27  Data_Scientist  Senior_level
# 28  Data_Scientist  Senior_level
# 29  Data_Scientist  Senior_level
# 30  Data_Scientist  Senior_level
# 31  Data_Scientist  Senior_level
# 32  Data_Scientist  Senior_level
# 33  Data_Scientist  Senior_level
# 34  Data_Scientist  Senior_level
# 35  Data_Scientist  Senior_level
# 36  Data_Scientist  Senior_level
# 37  Data_Scientist  Senior_level
# 38  Data_Scientist  Senior_level
# 39  Data_Scientist  Senior_level
# 40  Data_Scientist  Senior_level
# 41  Data_Scientist  Senior_level
# 42  Data_Scientist  Senior_level
# 43  Data_Scientist  Senior_level
# 44  Data_Scientist  Senior_level
# 45  Data_Scientist  Senior_level
# 46  Data_Scientist  Senior_level
# 47  Data_Scientist  Senior_level
# 48  Data_Scientist  Senior_level

# %%
## Data_scientist_SF_140_entry

driver = webdriver.Chrome()
url = "https://www.indeed.com/jobs?q=%22Data+Scientist%22+$140,000&l=San+Francisco,+CA&radius=50&explvl=entry_level&limit=100"
driver.get(url)
# wait one second
sleep(1)
#grab the page source
html = driver.page_source
# BeautifulSoup it!
html = BeautifulSoup(html)
driver.close()

# I'm going to create my empty df first
import pandas as pd
dcarea_job1 = pd.DataFrame(columns=["Company_name"])
dcarea_job2 = pd.DataFrame(columns=["Location","Salary", "Title","Experience"])
# loop through each entry
for company in html.find_all('span', {'class':'company'}):
    name_comp = company.text
    dcarea_job1.loc[len(dcarea_job1)]=[name_comp]
    
for location in html.find_all('span', {'class':'location'}):
    loc_comp = location.text
    salary = 140000
    experience = "Entry_level"
    # try to find the number of bookings
    title = "Data_Scientist"
    dcarea_job2.loc[len(dcarea_job2)]=[loc_comp,salary,title,experience]

dcarea_job1['Company_name'] = dcarea_job1['Company_name'].str.replace('\n', '')
dcarea_job2['Location'] = dcarea_job2['Location'].str.replace('\n', '')

result_SF_140_entry = pd.concat([dcarea_job1, dcarea_job2], axis=1)

result_SF_140_entry

## Data_scientist_SF_140_mid

driver = webdriver.Chrome()
url = "https://www.indeed.com/jobs?q=%22Data+Scientist%22+$140,000&l=San+Francisco,+CA&radius=50&explvl=mid_level&limit=100"
driver.get(url)
# wait one second
sleep(1)
#grab the page source
html = driver.page_source
# BeautifulSoup it!
html = BeautifulSoup(html)
driver.close()

# I'm going to create my empty df first
import pandas as pd
dcarea_job1 = pd.DataFrame(columns=["Company_name"])
dcarea_job2 = pd.DataFrame(columns=["Location","Salary", "Title","Experience"])
# loop through each entry
for company in html.find_all('span', {'class':'company'}):
    name_comp = company.text
    dcarea_job1.loc[len(dcarea_job1)]=[name_comp]
    
for location in html.find_all('span', {'class':'location'}):
    loc_comp = location.text
    salary = 140000
    experience = "Mid_level"
    # try to find the number of bookings
    title = "Data_Scientist"
    dcarea_job2.loc[len(dcarea_job2)]=[loc_comp,salary,title,experience]

dcarea_job1['Company_name'] = dcarea_job1['Company_name'].str.replace('\n', '')
dcarea_job2['Location'] = dcarea_job2['Location'].str.replace('\n', '')

result_SF_140_mid = pd.concat([dcarea_job1, dcarea_job2], axis=1)

result_SF_140_mid

## Data_scientist_SF_140_senior

driver = webdriver.Chrome()
url = "https://www.indeed.com/jobs?q=%22Data+Scientist%22+$140,000&l=San+Francisco,+CA&radius=50&explvl=senior_level&limit=100"
driver.get(url)
# wait one second
sleep(1)
#grab the page source
html = driver.page_source
# BeautifulSoup it!
html = BeautifulSoup(html)
driver.close()

# I'm going to create my empty df first
import pandas as pd
dcarea_job1 = pd.DataFrame(columns=["Company_name"])
dcarea_job2 = pd.DataFrame(columns=["Location","Salary", "Title","Experience"])
# loop through each entry
for company in html.find_all('span', {'class':'company'}):
    name_comp = company.text
    dcarea_job1.loc[len(dcarea_job1)]=[name_comp]
    
for location in html.find_all('span', {'class':'location'}):
    loc_comp = location.text
    salary = 140000
    experience = "Senior_level"
    # try to find the number of bookings
    title = "Data_Scientist"
    dcarea_job2.loc[len(dcarea_job2)]=[loc_comp,salary,title,experience]

dcarea_job1['Company_name'] = dcarea_job1['Company_name'].str.replace('\n', '')
dcarea_job2['Location'] = dcarea_job2['Location'].str.replace('\n', '')

result_SF_140_senior = pd.concat([dcarea_job1, dcarea_job2], axis=1)

result_SF_140_senior
# Out:
#                                          Company_name  \
# 0                                               Hired
# 1                                           Sigmaways
# 2                                          Change.org
# 3                                          TEKsystems
# 4                                  Gap Inc. Corporate
# 5                                 Cisco Systems, Inc.
# 6                               Workbridge Associates
# 7                               Bayone Solutions Inc.
# 8                                                eBay
# 9                                          Demandbase
# 10                                           TrialPay
# 11                                           Datameer
# 12                              Workbridge Associates
# 13                              InsideSales.com, Inc.
# 14                                           Ancestry
# 15                                               Arka
# 16                                 Jobspring Partners
# 17                                          Capgemini
# 18                                Cisco Systems, Inc.
# 19                                             Intuit
# 20                                             EOS DA
# 21                                          Accenture
# 22      Redfish Technology - High Tech Executive R...
# 23                                          Accenture
# 24                                         GE Careers
# 25                                         GE Careers
# 26                                          Accenture
#
#                                              Location    Salary  \
# 0                                   San Francisco, CA  140000.0
# 1                                       Palo Alto, CA  140000.0
# 2      San Francisco, CA 94103 (South Of Market area)  140000.0
# 3      San Francisco, CA 94103 (South Of Market area)  140000.0
# 4                                   San Francisco, CA  140000.0
# 5                                        San Jose, CA  140000.0
# 6   San Francisco, CA 94105 (Financial District area)  140000.0
# 7                                   San Francisco, CA  140000.0
# 8                                        San Jose, CA  140000.0
# 9                                   San Francisco, CA  140000.0
# 10                                  Mountain View, CA  140000.0
# 11     San Francisco, CA 94103 (South Of Market area)  140000.0
# 12                                  San Francisco, CA  140000.0
# 13                                      San Mateo, CA  140000.0
# 14                                  San Francisco, CA  140000.0
# 15                                  San Francisco, CA  140000.0
# 16                 San Jose, CA 95113 (Downtown area)  140000.0
# 17                            South San Francisco, CA  140000.0
# 18                                       San Jose, CA  140000.0
# 19                            Mountain View, CA 94039  140000.0
# 20                                     Menlo Park, CA  140000.0
# 21  San Francisco, CA 94105 (Financial District area)  140000.0
# 22                                  San Francisco, CA  140000.0
# 23  San Francisco, CA 94105 (Financial District area)  140000.0
# 24                                San Ramon, CA 94583  140000.0
# 25                                San Ramon, CA 94583  140000.0
# 26  San Francisco, CA 94105 (Financial District area)  140000.0
#
#              Title    Experience
# 0   Data_Scientist  Senior_level
# 1   Data_Scientist  Senior_level
# 2   Data_Scientist  Senior_level
# 3   Data_Scientist  Senior_level
# 4   Data_Scientist  Senior_level
# 5   Data_Scientist  Senior_level
# 6   Data_Scientist  Senior_level
# 7   Data_Scientist  Senior_level
# 8   Data_Scientist  Senior_level
# 9   Data_Scientist  Senior_level
# 10  Data_Scientist  Senior_level
# 11  Data_Scientist  Senior_level
# 12  Data_Scientist  Senior_level
# 13  Data_Scientist  Senior_level
# 14  Data_Scientist  Senior_level
# 15  Data_Scientist  Senior_level
# 16  Data_Scientist  Senior_level
# 17  Data_Scientist  Senior_level
# 18  Data_Scientist  Senior_level
# 19  Data_Scientist  Senior_level
# 20  Data_Scientist  Senior_level
# 21  Data_Scientist  Senior_level
# 22  Data_Scientist  Senior_level
# 23  Data_Scientist  Senior_level
# 24  Data_Scientist  Senior_level
# 25  Data_Scientist  Senior_level
# 26  Data_Scientist  Senior_level

# %% [markdown]
# ## Data Science dataset

# %%
result_DC_Data_Scientist = pd.concat([result_DC_75_entry,result_DC_75_mid,result_DC_75_senior,result_DC_90_entry,result_DC_90_mid,result_DC_90_senior,result_DC_105_entry,result_DC_105_mid,result_DC_105_senior,result_DC_110_entry,result_DC_110_mid,result_DC_110_senior,result_DC_125_entry,result_DC_125_mid,result_DC_125_senior])

# %%
result_DC_Data_Scientist.shape
# Out:
# (717, 5)

# %%
result_NY_Data_Scientist = pd.concat([result_NY_85_entry,result_NY_85_mid,result_NY_85_senior,result_NY_100_entry,result_NY_100_mid,result_NY_100_senior,result_NY_115_entry,result_NY_115_mid,result_NY_115_senior,result_NY_125_entry,result_NY_125_mid,result_NY_125_senior,result_NY_140_entry,result_NY_140_mid,result_NY_140_senior])

# %%
result_NY_Data_Scientist.shape
# Out:
# (787, 5)

# %%
result_SF_Data_Scientist = pd.concat([result_SF_90_entry,result_SF_90_mid,result_SF_90_senior,result_SF_105_entry,result_SF_105_mid,result_SF_105_senior,result_SF_115_entry,result_SF_115_mid,result_SF_115_senior,result_SF_125_entry,result_SF_125_mid,result_SF_125_senior,result_SF_140_entry,result_SF_140_mid,result_SF_140_senior])

# %%
result_SF_Data_Scientist.shape
# Out:
# (1054, 5)

# %%
result_SF_Data_Scientist.to_csv('result_SF_Data_Scientist.csv', encoding='utf-8')

# %%
result_NY_Data_Scientist.to_csv('result_NY_Data_Scientist.csv', encoding='utf-8')

# %%
result_DC_Data_Scientist.to_csv('result_DC_Data_Scientist.csv', encoding='utf-8')

# %%
result_Data_Scientist = pd.concat([result_DC_Data_Scientist,result_NY_Data_Scientist,result_SF_Data_Scientist])

# %%
result_Data_Scientist.shape
# Out:
# (2558, 5)

# %%
result_Data_Scientist.to_csv('result_Data_Scientist.csv', encoding='utf-8')
